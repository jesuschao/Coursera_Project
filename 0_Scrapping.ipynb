# %% [markdown]
# # Scrapping

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium.webdriver.chrome.options import Options

# %%
import pandas as pd

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver,options = opciones)

# %%
import time

import warnings   # para quitar warnings
warnings.simplefilter('ignore')

# %%
url='https://www.coursera.org/search?query=&index=prod_all_launched_products_term_optimization'

# %%
PATH=ChromeDriverManager().install()
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the any command: google-chrome --version || google-chrome-stable --version
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Driver [/home/jesus_chao/.wdm/drivers/chromedriver/linux64/99.0.4844.51/chromedriver] found in cache

# %%
driver.get(url)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
    rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
p_course = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/h2"
p_rating = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]"
p_students = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span"
p_level = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span"
p_university = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/div[1]/div[2]/span"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-9575f0053ca2> in <module>
# ----> 1 p_course = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/h2"
#       2 p_rating = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]"
#       3 p_students = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span"
#       4 p_level = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span"
#       5 p_university = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/div[1]/div[2]/span"
#
# NameError: name 'a' is not defined

# %%
p_level_alt = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span"
p_university_alt = f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/div[1]/div[2]/span"

# %%
click = "//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div/button[7]"

# %%
def coursera(num_pages, query):
    
    URL='https://www.coursera.org/search/'
    
    course =[]
    rating=[]
    students=[]
    level=[]
    university =[]

    for i in range(1, num_pages):

        scrape_url=''.join([
            URL,  # url base
            f'?query={query}',   # palabras clave de busqueda
            f'&page={i}', # numero de paginas (i)
            '&page=1&index=prod_all_launched_products_term_optimization'
            ])

        driver.get(scrape_url)  # el html de la pagina
        
        
        for a in range(1,11):
           
            try:
                course.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/h2").text)
            
            except:
                
                course.append(None)
            try:
                rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
            
            except:
                
                rating.append(None)
                
            time.sleep(t)
            
            try:
                
                students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
            
            except:
                
                students.append(None)
            
            time.sleep(t)
            
            try:
                
                level.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
                                        
            except:
                
                level.append(None)
            
            time.sleep(t)
            
            try:
                university.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{a}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
            
            except:     
        
                university.append(None)
            
            """data =pd.DataFrame()
            data['course'] =course
            data['rating'] =rating
            data['students'] =students
            data['level'] =level
            data['university'] =university
            
            time.sleep(t)
            data.to_csv(f"{query}.{i}.csv")"""
            
            time.sleep(t)
            siguiente = driver.find_element_by_xpath("//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/div[2]/div/button[7]")
            siguiente.click()
            time.sleep(t)
            
    
        data_final =pd.DataFrame()
        data_final['course'] =course
        data_final['rating'] =rating
        data_final['students'] =students
        data_final['level'] =level
        data_final['university'] =university
        
        data_final.to_csv(f"{query}_final.csv")
            
        return data_final

# %%
coursera(6, "mysql")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %%
# Como no me ha funcionado por ahora la función he escrapeado los datos página por página para las siguientes búsquedas:
# MySQL, Mongo, Python, Tableau y Machine Learning.
#Aun así tengo `pendiente arreglarlo.

# %% [markdown]
# ### MySQL Courses

# %%
# Repito código porque escrapeo página por página. He escrapeado 6 páginas de MySQL (60 cursos).

# %%
url1 = "https://www.coursera.org/search?query=mysql&index=prod_all_launched_products_term_optimization"
driver.get(url1)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")
        
mysql=pd.DataFrame()
mysql['course'] =curso
mysql['rating'] = rating
mysql['students'] =students
mysql['level'] = nivel
mysql['university'] = universidad

mysql
# Out:
#                                               course rating students level  \
# 0                  Learn SQL Basics for Data Science    4.6  400 mil   4.6
# 1   Excel to MySQL: Analytic Techniques for Business    4.6  660 mil   4.6
# 2    Introduction to Structured Query Language (SQL)    4.8  140 mil   4.8
# 3                       Managing Big Data with MySQL    4.7  170 mil   4.7
# 4       Complex Retrieval Queries in MySQL Workbench    4.3     None   4.3
# 5                               SQL for Data Science    4.6  390 mil   4.6
# 6       Building a Dynamic Web App using PHP & MySQL    4.4  5,8 mil   4.4
# 7  Building a Company’s database using MySQL and SQL    4.5     None   4.5
# 8                           Data Science Math Skills    4.5  300 mil   4.5
# 9        Introduction to Relational Database and SQL    4.6   28 mil   4.6
#
#                         university
# 0  University of California, Davis
# 1                  Duke University
# 2           University of Michigan
# ...

# %%
url2 = "https://www.coursera.org/search?query=mysql&page=2&index=prod_all_launched_products_term_optimization"
driver.get(url2)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mysql2=pd.DataFrame()
mysql2['course'] =curso
mysql2['rating'] =rating
mysql2['students'] =students
mysql2['level'] =nivel
mysql2['university'] = universidad

mysql2
# Out:
#                                               course rating students level  \
# 0            Create a Python Application using MySQL    4.5    5 mil   4.5
# 1       Introduction to Relational Databases (RDBMS)    4.6  8,6 mil   4.6
# 2                        Analyzing Big Data with SQL    4.9   22 mil   4.9
# 3  Create a Database with the Modeling Tool in My...    4.7  1,9 mil   4.7
# 4            Clean Data in SQL using MySQL Workbench   None     None  None
# 5        Simple Retrieval Queries in MySQL Workbench    4.6    2 mil   4.6
# 6          Build Messenger Clone Using PHP and MySQL   None     None  None
# 7       Working with MySQL DB instance using AWS RDS    4.7     None   4.7
# 8                      Using MySQL Database with PHP   None     None  None
# 9                  MySQL with Information Technology    4.9     None   4.9
#
#                  university
# 0  Coursera Project Network
# 1                       IBM
# 2                  Cloudera
# ...

# %%
url3 = "https://www.coursera.org/search?query=mysql&page=3&index=prod_all_launched_products_term_optimization"
driver.get(url3)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mysql3=pd.DataFrame()
mysql3['course'] =curso
mysql3['rating'] =rating
mysql3['students'] =students
mysql3['level'] =nivel
mysql3['university'] =universidad

mysql3
# Out:
#                                               course rating students level  \
# 0  Data Manipulation and Management using MYSQL W...   None     None  None
# 1  Sort and Filter Data in SQL using MySQL Workbench   None     None  None
# 2  Database Creation and Modeling using MYSQL Wor...      5     None     5
# 3                       MySQL تكنولوجيا المعلومات مع   None     None  None
# 4  MYSQL Workbench إنشاء و تصميم قواعد البيانات ب...   None     None  None
# 5        Aggregate Data in SQL using MySQL Workbench   None     None  None
# 6         Validate Data in SQL using MySQL Workbench   None     None  None
# 7        Calculate Data in SQL using MySQL Workbench   None     None  None
# 8  Relational Databases - MySQL - قواعد البيانات ...   None     None  None
# 9               Microsoft Azure Relational Databases    4.9     None   4.9
#
#                  university
# 0  Coursera Project Network
# 1  Coursera Project Network
# 2  Coursera Project Network
# ...

# %%
url4 = "https://www.coursera.org/search?query=mysql&page=4&index=prod_all_launched_products_term_optimization"
driver.get(url4)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mysql4=pd.DataFrame()
mysql4['course'] =curso
mysql4['rating'] =rating
mysql4['students'] =students
mysql4['level'] =nivel
mysql4['university'] =universidad

mysql4
# Out:
#                                               course rating students level  \
# 0              Deploy a Wordpress Website in AWS EC2    4.7  1,8 mil   4.7
# 1                     Database Management Essentials    4.6  170 mil   4.6
# 2           Intermediate Relational Database and SQL    4.4   11 mil   4.4
# 3                   Building Web Applications in PHP    4.7  130 mil   4.7
# 4  Google Cloud Big Data and Machine Learning Fun...    4.5  4,5 mil   4.5
# 5  Data Warehouse Concepts, Design, and Data Inte...    4.4   56 mil   4.4
# 6              Building Database Applications in PHP    4.9   41 mil   4.9
# 7  Google Cloud Big Data and Machine Learning Fun...    4.3    2 mil   4.3
# 8                        Relational database systems    4.4   20 mil   4.4
# 9  Google Cloud Big Data and Machine Learning Fun...    4.7   18 mil   4.7
#
#                                 university
# 0                 Coursera Project Network
# 1            University of Colorado System
# ...

# %%
url5 = "https://www.coursera.org/search?query=mysql&page=5&index=prod_all_launched_products_term_optimization"
driver.get(url5)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mysql5=pd.DataFrame()
mysql5['course'] =curso
mysql5['rating'] =rating
mysql5['students'] =students
mysql5['level'] =nivel
mysql5['university'] =universidad

mysql5
# Out:
#                                               course rating students level  \
# 0                                          SQL Joins    4.7  2,9 mil   4.7
# 1  Data-Driven Testing (via Database) with Seleni...    4.9     None   4.9
# 2  Google Cloud Platform Big Data and Machine Lea...    4.8    2 mil   4.8
# 3         Business intelligence and data warehousing    3.9   11 mil   3.9
# 4  Increasing Real Estate Management Profits: Har...    4.7   13 mil   4.7
# 5                           Cloud Computing Security    4.6   13 mil   4.6
# 6  Introduction To Java Database Connectivity - JDBC    4.3     None   4.3
# 7          Introducción a las bases relacionales SQL   None     None  None
# 8                    Learn PHP Database Connectivity    4.7     None   4.7
# 9                 How to Use SQL with Large Datasets   None     None  None
#
#                                 university
# 0                 Coursera Project Network
# 1                 Coursera Project Network
# ...

# %%
url6 = "https://www.coursera.org/search?query=mysql&page=6&index=prod_all_launched_products_term_optimization"
driver.get(url6)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"/html/body/div[3]/div/div/main/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mysql6=pd.DataFrame()
mysql6['course'] =curso
mysql6['rating'] =rating
mysql6['students'] =students
mysql6['level'] =nivel
mysql6['university'] =universidad

mysql6
# Out:
#                                               course rating students level  \
# 0    Create your first Amazon Aurora Database in AWS    4.8     None   4.8
# 1                          تعليم مبادئ ال SQL Syntax   None     None  None
# 2             Combine Multiple Pieces of Data in SQL   None     None  None
# 3  Data-Driven Testing (via Database) with Seleni...   None     None  None
# 4  Set up your dev environment for LAMP web devel...   None     None  None
# 5       Introdução à base de dados relacionais e SQL   None     None  None
# 6  Deploy a Complete Wordpress Video Blog in Micr...   None     None  None
# 7                   Introduction to Forensic Science    4.9  110 mil   4.9
# 8         Excel Skills for Business: Intermediate II    4.8  150 mil   4.8
# 9                  Introduction to Economic Theories    4.5   52 mil   4.5
#
#                                     university
# 0                     Coursera Project Network
# 1                     Coursera Project Network
# ...

# %%
mysql = pd.concat([mysql, mysql2, mysql3, mysql4, mysql5,mysql6])

# %%
mysql = mysql.reset_index()

# %%
mysql.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(60):
    lista.append("MySQL")

# %%
mysql['skills'] = lista

# %%
mysql
# Out:
#                                                course rating students level  \
# 0                   Learn SQL Basics for Data Science    4.6  400 mil   4.6
# 1    Excel to MySQL: Analytic Techniques for Business    4.6  660 mil   4.6
# 2     Introduction to Structured Query Language (SQL)    4.8  140 mil   4.8
# 3                        Managing Big Data with MySQL    4.7  170 mil   4.7
# 4        Complex Retrieval Queries in MySQL Workbench    4.3     None   4.3
# 5                                SQL for Data Science    4.6  390 mil   4.6
# 6        Building a Dynamic Web App using PHP & MySQL    4.4  5,8 mil   4.4
# 7   Building a Company’s database using MySQL and SQL    4.5     None   4.5
# 8                            Data Science Math Skills    4.5  300 mil   4.5
# 9         Introduction to Relational Database and SQL    4.6   28 mil   4.6
# 10            Create a Python Application using MySQL    4.5    5 mil   4.5
# ...

# %%
mysql.to_csv("mysql.csv")

# %% [markdown]
# ### MongoDB Courses

# %%
# Repito código porque escrapeo página por página. He escrapeado 14 páginas de Mongo DB (140 cursos).

# %%
mongo1 = "https://www.coursera.org/search?query=mongo&index=prod_all_launched_products_term_optimization"
driver.get(mongo1)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo1=pd.DataFrame()
mongo1['course'] =curso
mongo1['rating'] =rating
mongo1['students'] =students
mongo1['level'] =nivel
mongo1['university'] =universidad

mongo1
# Out:
#                                               course rating students  \
# 0  Server-side Development with NodeJS, Express a...    4.7  130 mil
# 1                            Introduction to MongoDB    4.2   52 mil
# 2    Introducción a bases de datos NoSQL con MongoDB   None     None
# 3    Create a C# Application to process MongoDB Data   None     None
# 4  Create a Python Application using PyMongo and ...    4.4  3,2 mil
# 5                      MongoDB Aggregation Framework    4.5  8,7 mil
# 6  Use the Apache Spark Structured Streaming API ...   None     None
# 7  Web Application Development with JavaScript an...    4.6   59 mil
# 8  Create Your First NoSQL Database with MongoDB ...    4.6  2,8 mil
# 9                CRUD Operations using MongoDB NoSQL    4.4  1,7 mil
#
#           level                                         university
# 0  Intermediate  The Hong Kong University of Science and Techno...
# 1  Intermediate                                       MongoDB Inc.
# ...

# %%
mongo2 = "https://www.coursera.org/search?query=mongo&page=2&index=prod_all_launched_products_term_optimization"
driver.get(mongo2)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo2=pd.DataFrame()
mongo2['course'] =curso
mongo2['rating'] =rating
mongo2['students'] =students
mongo2['level'] =nivel
mongo2['university'] =universidad

mongo2
# Out:
#                                               course rating students  \
# 0  Desarrollo del lado servidor: NodeJS, Express ...    4.1   11 mil
# 1              Create Fault Tolerant MongoDB Cluster      5     None
# 2  Crea ambientes MERN (MongoDB, Express, React, ...   None     None
# 3                    Introduction to NoSQL Databases    4.6  6,8 mil
# 4              Designing data-intensive applications    4.5  6,2 mil
# 5              Full-Stack Web Development with React    4.7  360 mil
# 6            Full Stack Web Development with Angular    4.7  350 mil
# 7           Build a Node Server backend with Express   None     None
# 8           Responsive Website Tutorial and Examples    4.2   35 mil
# 9             NoSQL, Big Data, and Spark Foundations    4.3   11 mil
#
#           level                                         university
# 0      Beginner                                Universidad Austral
# 1  Intermediate                           Coursera Project Network
# ...

# %%
mongo3 = "https://www.coursera.org/search?query=mongo&page=3&index=prod_all_launched_products_term_optimization"
driver.get(mongo3)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo3=pd.DataFrame()
mongo3['course'] =curso
mongo3['rating'] =rating
mongo3['students'] =students
mongo3['level'] =nivel
mongo3['university'] =universidad

mongo3
# Out:
#                                               course rating students  \
# 0          Responsive Website Development and Design    4.5  250 mil
# 1        Network Security & Database Vulnerabilities    4.7   46 mil
# 2                                  History of Russia    4.4     None
# 3              Introduction to Meteor.js Development    4.6   43 mil
# 4                              Working with Big Data   None     None
# 5  Containerize a full-stack NodeJS application i...    4.5  2,7 mil
# 6  The amazing world of the ethnic groups of Yunn...   None     None
# 7                      بناء Backend لنسخة من Twitter   None     None
# 8     Build a Full Stack App using React and Express   None     None
# 9                  Microeconomics: When Markets Fail    4.8   29 mil
#
#           level                         university
# 0      Beginner               University of London
# 1      Beginner                                IBM
# 2      Beginner  Saint Petersburg State University
# ...

# %%
mongo4 = "https://www.coursera.org/search?query=mongo&page=4&index=prod_all_launched_products_term_optimization"
driver.get(mongo4)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo4=pd.DataFrame()
mongo4['course'] =curso
mongo4['rating'] =rating
mongo4['students'] =students
mongo4['level'] =nivel
mongo4['university'] =universidad

mongo4
# Out:
#                                      course rating students         level  \
# 0                    إلهام الأفراد وتحفيزهم   None     None         Mixed
# 1      Microeconomics: The Power of Markets    4.7   50 mil         Mixed
# 2        Cómo inspirar y a motivar personas   None     None         Mixed
# 3      Inspiração e motivação de indivíduos   None     None         Mixed
# 4                        Business Analytics    4.6  370 mil      Beginner
# 5                  Leading People and Teams    4.7  350 mil      Beginner
# 6              Marketing Mix Implementation    4.7  160 mil      Beginner
# 7     Business English Communication Skills    4.8  240 mil  Intermediate
# 8  Business English: Planning & Negotiating    4.8   45 mil  Intermediate
# 9                      Accounting Analytics    4.5   95 mil         Mixed
#
#                    university
# 0      University of Michigan
# 1  University of Pennsylvania
# 2      University of Michigan
# ...

# %%
mongo5 = "https://www.coursera.org/search?query=mongo&page=5&index=prod_all_launched_products_term_optimization"
driver.get(mongo5)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo5=pd.DataFrame()
mongo5['course'] =curso
mongo5['rating'] =rating
mongo5['students'] =students
mongo5['level'] =nivel
mongo5['university'] =universidad

mongo5
# Out:
#                                               course rating students  \
# 0               Inspiring and Motivating Individuals    4.8  170 mil
# 1                       Brand and Product Management    4.7   82 mil
# 2                       Business English: Networking    4.8  170 mil
# 3  Lesson | Business English Skills: How to Write...    4.4   50 mil
# 4  Lesson | Business English Skills: How to Navig...    4.5   28 mil
# 5  Lesson | Business English Skills: Introducing ...    4.3   21 mil
# 6  Migrating a Monolithic Website to Microservice...    4.7     None
# 7          Create a C# UI on Linux using MonoDevelop   None     None
# 8                              Design of Experiments    4.7   12 mil
# 9                                   Spring Framework    3.7  5,6 mil
#
#           level                university
# 0         Mixed    University of Michigan
# 1         Mixed        IE Business School
# 2  Intermediate  University of Washington
# ...

# %%
mongo6 = "https://www.coursera.org/search?query=mongo&page=6&index=prod_all_launched_products_term_optimization"
driver.get(mongo6)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo6=pd.DataFrame()
mongo6['course'] =curso
mongo6['rating'] =rating
mongo6['students'] =students
mongo6['level'] =nivel
mongo6['university'] =universidad

mongo6
# Out:
#                                               course rating students  \
# 0         Building Containerized Applications on AWS    4.5   20 mil
# 1  Internet Giants: The Law and Economics of Medi...    4.8   53 mil
# 2                        Introduction to solar cells    4.8   53 mil
# 3                                        Natural Gas    4.7   28 mil
# 4     Smart Working: Lavoro agile e Business English   None     None
# 5     Real-Time Embedded Systems Theory and Analysis    4.4  3,4 mil
# 6  Basic Cryptography and Programming with Crypto...    4.3   11 mil
# 7   Administrasi Sistem dan Layanan Infrastruktur TI      5     None
# 8  Sistem Operasi dan Anda: Menjadi Pengguna yang...    4.9     None
# 9                    结构生物化学（Structural Biochemistry)    4.8   12 mil
#
#           level                             university
# 0         Mixed                    Amazon Web Services
# 1         Mixed              The University of Chicago
# ...

# %%
mongo7 = "https://www.coursera.org/search?query=mongo&page=7&index=prod_all_launched_products_term_optimization"
driver.get(mongo7)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo7=pd.DataFrame()
mongo7['course'] =curso
mongo7['rating'] =rating
mongo7['students'] =students
mongo7['level'] =nivel
mongo7['university'] =universidad

mongo7
# Out:
#                                               course rating students  \
# 0                            Spring - Cloud Overview    4.5     None
# 1                                  IBM Data Topology    4.8  1,5 mil
# 2  The Power of Markets III: Input Markets and Pr...    4.8  4,3 mil
# 3  Customizing color pickers and swatches in Adob...   None     None
# 4  Creating Azure Serverless Functions in a Real-...   None     None
# 5  Diseño Instruccional: Aprendizaje activo y Ped...    4.7   14 mil
# 6                   Digital Marketing for E-commerce    4.4  2,3 mil
# 7      Foundations of Healthcare Systems Engineering    4.6  5,2 mil
# 8                         Experimental Design Basics    4.7   11 mil
# 9    Diseño instruccional para el aprendizaje activo    4.7   11 mil
#
#           level                university
# 0  Intermediate                LearnQuest
# 1  Intermediate                       IBM
# 2         Mixed   University of Rochester
# ...

# %%
mongo8 = "https://www.coursera.org/search?query=mongo&page=8&index=prod_all_launched_products_term_optimization"
driver.get(mongo8)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo8=pd.DataFrame()
mongo8['course'] =curso
mongo8['rating'] =rating
mongo8['students'] =students
mongo8['level'] =nivel
mongo8['university'] =universidad

mongo8
# Out:
#                                               course rating students  \
# 0                        E-Business: Negocios Online    4.6  6,9 mil
# 1         Factorial and Fractional Factorial Designs    4.8  3,3 mil
# 2  La formación del pensamiento crítico en la era...    4.8     None
# 3    Response Surfaces, Mixtures, and Model Building    4.7  2,5 mil
# 4       Random Models, Nested and Split-plot Designs    4.6    2 mil
# 5  Modelos de diseño instruccional para ambientes...    4.7  4,7 mil
# 6  Proyecto de diseño instruccional para el apren...    4.6  2,8 mil
# 7       UX and Interface Design for Embedded Systems      4  2,7 mil
# 8  M2M & IoT Interface Design & Protocols for Emb...    3.7     None
# 9    Rapid Prototyping of Embedded Interface Designs   None     None
#
#           level                         university
# 0      Beginner             Universidad de Palermo
# 1  Intermediate           Arizona State University
# 2      Beginner  Universitat Autònoma de Barcelona
# ...

# %%
mongo9 = "https://www.coursera.org/search?query=mongo&page=9&index=prod_all_launched_products_term_optimization"
driver.get(mongo9)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo9=pd.DataFrame()
mongo9['course'] =curso
mongo9['rating'] =rating
mongo9['students'] =students
mongo9['level'] =nivel
mongo9['university'] =universidad

mongo9
# Out:
#                                               course rating students  \
# 0  Oralpha: Literacy for new citizens, a course f...   None     None
# 1                          Embedded Interface Design    3.7  4,2 mil
# 2  Master of Science in Machine Learning and Data...   None     None
# 3                                         Blockchain    4.6  190 mil
# 4  Photography Basics and Beyond: From Smartphone...    4.7  270 mil
# 5                            Social Media Management    4.9   70 mil
# 6  International Humanitarian Law in Theory and P...    4.8   41 mil
# 7                              Healthcare IT Support    4.7  7,5 mil
# 8                                 Precision Medicine      4  7,5 mil
# 9                            Suporte em TI do Google    4.9   18 mil
#
#           level                         university
# 0      Beginner  Universitat Autònoma de Barcelona
# 1  Intermediate     University of Colorado Boulder
# 2          None            Imperial College London
# ...

# %%
mongo10 = "https://www.coursera.org/search?query=mongo&page=10&index=prod_all_launched_products_term_optimization"
driver.get(mongo10)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo10=pd.DataFrame()
mongo10['course'] =curso
mongo10['rating'] =rating
mongo10['students'] =students
mongo10['level'] =nivel
mongo10['university'] =universidad

mongo10
# Out:
#                                               course rating students  \
# 0  Investment Management in an Evolving and Volat...    4.6   44 mil
# 1                     Electric Vehicles and Mobility    4.5   35 mil
# 2                     Diabetes – the Essential Facts    4.7   59 mil
# 3  Negociações de sucesso: estratégias e habilida...    4.9   70 mil
# 4           Leadership in 21st Century Organizations    4.7   58 mil
# 5  Faster Together, Enhancing the Recruitment of ...    4.8  2,5 mil
# 6          Designing Effective Science Communication    4.5     None
# 7            Marketing de Mídias Sociais do Facebook    4.8     None
# 8                          Data and Urban Governance   None     None
# 9           Relational Database Administration (DBA)      5  2,2 mil
#
#           level                      university
# 0  Intermediate                       HEC Paris
# 1      Beginner       École des Ponts ParisTech
# 2      Beginner        University of Copenhagen
# ...

# %%
mongo11 = "https://www.coursera.org/search?query=mongo&page=11&index=prod_all_launched_products_term_optimization"
driver.get(mongo11)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo11=pd.DataFrame()
mongo11['course'] =curso
mongo11['rating'] =rating
mongo11['students'] =students
mongo11['level'] =nivel
mongo11['university'] =universidad

mongo11
# Out:
#                                               course rating students  \
# 0  Impacting the Opioid Crisis: Prevention, Educa...    4.9  3,6 mil
# 1                                      Trademark Law    4.8  6,1 mil
# 2            Inteligência Artificial Aplicada ao CRM   None     None
# 3  Economic systems in different countries of the...   None     None
# 4                      Writing and Editing: Drafting    4.8   12 mil
# 5  Gestão de produtos digitais: Princípios básico...    4.9     None
# 6  Life After COVID-19: Get Ready for our Post-Pa...    4.8  4,8 mil
# 7  Kids with Cancer Still Need School: The Provid...   None     None
# 8                       When Disaster Meets Conflict    4.8  3,5 mil
# 9  Professional development: Improve yourself, al...    4.8   17 mil
#
#           level                                university
# 0      Beginner                    University of Michigan
# 1         Mixed                University of Pennsylvania
# ...

# %%
mongo12 = "https://www.coursera.org/search?query=mongo&page=12&index=prod_all_launched_products_term_optimization"
driver.get(mongo12)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo12=pd.DataFrame()
mongo12['course'] =curso
mongo12['rating'] =rating
mongo12['students'] =students
mongo12['level'] =nivel
mongo12['university'] =universidad

mongo12
# Out:
#                                               course rating students  \
# 0         PrEParing: PrEP for Providers and Patients    4.7  5,4 mil
# 1    Digital Business - Understand the digital world    4.4     None
# 2  Operations and Patient Safety for Healthcare I...    4.8  2,3 mil
# 3            Career planning: Your career, your life    4.8  7,5 mil
# 4                   Strategic Career Self-Management    4.5   37 mil
# 5  How to Use the Lean Canvas to Validate Your Bu...   None     None
# 6  How to Get Skilled: Introduction to Individual...    3.8   51 mil
# 7              Russian Invasion of Ukraine Teach-Out   None     None
# 8                                      NoSQL systems    4.3  9,8 mil
# 9                               Giving 2.0: The MOOC    4.6   30 mil
#
#           level                               university
# 0      Beginner                 Johns Hopkins University
# 1         Mixed                   Institut Mines-Télécom
# ...

# %%
mongo13 = "https://www.coursera.org/search?query=mongo&page=13&index=prod_all_launched_products_term_optimization"
driver.get(mongo13)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo13=pd.DataFrame()
mongo13['course'] =curso
mongo13['rating'] =rating
mongo13['students'] =students
mongo13['level'] =nivel
mongo13['university'] =universidad

mongo13
# Out:
#                                               course rating students  \
# 0  PRINCÍPIOS GERAIS DA TÉCNICA DO VIOLINO E DA V...    4.9  2,1 mil
# 1    Health, Society, and Wellness in COVID-19 Times    4.7     None
# 2                             Capitalismo Consciente    4.5   12 mil
# 3                   Sistemática de Comércio Exterior   None     None
# 4  Google Cloud Product Fundamentals em Português...    4.6     None
# 5                          Controle a Tempo Discreto   None     None
# 6                            Transportes e Logística   None     None
# 7         Design Research para Estratégia e Inovação   None     None
# 8  In the footsteps of Zika… approaching the unknown    4.7  5,3 mil
# 9                         Finanças Orientada a Dados   None     None
#
#           level                            university
# 0  Intermediate     Universidade Estadual de Campinas
# 1      Beginner        University of Colorado Boulder
# ...

# %%
mongo14 = "https://www.coursera.org/search?query=mongo&page=14&index=prod_all_launched_products_term_optimization"
driver.get(mongo14)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

mongo14=pd.DataFrame()
mongo14['course'] =curso
mongo14['rating'] =rating
mongo14['students'] =students
mongo14['level'] =nivel
mongo14['university'] =universidad

mongo14
# Out:
#                                               course rating students  \
# 0  Explorando os recursos educacionais da Khan Ac...    4.8  6,5 mil
# 1  Business Transformation with Google Cloud em P...    4.9     None
# 2  Gestão de Stakeholders, Ética e Sustentabilida...   None     None
# 3              Vieses Inconscientes e Comportamentos   None     None
# 4  Validating Your Business Model with Innovator’...   None     None
# 5                 Fundamentos de IA Aplicados ao CRM   None     None
# 6  Conclusão do Marketing de Mídias Sociais do Fa...   None     None
# 7                            Vozes da Mudança Social    4.8     None
# 8             Introdução a Mapas de Relação com Kumu   None     None
# 9        Fundamentos da Gestão do Sucesso do Cliente   None     None
#
#           level                           university
# 0         Mixed                      Fundação Lemann
# 1      Beginner                         Google Cloud
# ...

# %%
mongofinal = pd.concat([mongo1, mongo2, mongo3, mongo4, mongo5, mongo6, mongo7, mongo8, mongo9, mongo10, mongo11, mongo12, mongo12, mongo14])

# %%
mongofinal = mongofinal.reset_index()

# %%
mongofinal.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(140):
    lista.append("MongoDB")

# %%
mongofinal['skills'] = lista

# %%
mongofinal
# Out:
#                                                 course rating students  \
# 0    Server-side Development with NodeJS, Express a...    4.7  130 mil
# 1                              Introduction to MongoDB    4.2   52 mil
# 2      Introducción a bases de datos NoSQL con MongoDB   None     None
# 3      Create a C# Application to process MongoDB Data   None     None
# 4    Create a Python Application using PyMongo and ...    4.4  3,2 mil
# ..                                                 ...    ...      ...
# 135                 Fundamentos de IA Aplicados ao CRM   None     None
# 136  Conclusão do Marketing de Mídias Sociais do Fa...   None     None
# 137                            Vozes da Mudança Social    4.8     None
# 138             Introdução a Mapas de Relação com Kumu   None     None
# 139        Fundamentos da Gestão do Sucesso do Cliente   None     None
#
#             level                                         university   skills
# ...

# %%
mongofinal.to_csv("mongo.csv")

# %% [markdown]
# ### TABLEAU COURSES

# %%
# Repito código porque escrapeo página por página. He escrapeado 7 páginas de Tableau (70 cursos).

# %%
tableau1 = "https://www.coursera.org/search?query=tableau&index=prod_all_launched_products_term_optimization"
driver.get(tableau1)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

tableau1=pd.DataFrame()
tableau1['course'] =curso
tableau1['rating'] =rating
tableau1['students'] =students
tableau1['level'] =nivel
tableau1['university'] =universidad

tableau1
# Out:
#                                               course rating students  \
# 0                    Data Visualization with Tableau    4.5  170 mil
# 1                              Google Data Analytics    4.8  740 mil
# 2  Data Visualization and Communication with Tableau    4.7  190 mil
# 3   Excel to MySQL: Analytic Techniques for Business    4.6  660 mil
# 4             Анализ и визуализация данных в Tableau    4.8     None
# 5         Fundamentals of Visualization with Tableau    4.5  150 mil
# 6            Visualizing Citibike Trips with Tableau    4.6   17 mil
# 7  Creating Dashboards and Storytelling with Tableau    4.6   41 mil
# 8         Use Tableau for Your Data Science Workflow    4.6     None
# 9                        Advanced Business Analytics    4.6  210 mil
#
#           level                                  university
# 0      Beginner             University of California, Davis
# 1      Beginner                                      Google
# ...

# %%
tableau2 = "https://www.coursera.org/search?query=tableau&page=2&index=prod_all_launched_products_term_optimization"
driver.get(tableau2)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")
        
tableau2=pd.DataFrame()
tableau2['course'] =curso
tableau2['rating'] =rating
tableau2['students'] =students
tableau2['level'] =nivel
tableau2['university'] =universidad

tableau2
# Out:
#                                               course rating students  \
# 0  Create a Big Number KPI Dashboard in Tableau P...    3.4     None
# 1  Creating an Interactive KPI Management Dashboa...    4.3     None
# 2              Analyze City Data Using R and Tableau      4     None
# 3            Data Visualization with Tableau Project    4.6   24 mil
# 4  Fundamentos de la visualización de datos con T...    4.7     None
# 5         Principios esenciales de diseño en Tableau    4.3     None
# 6        Share Data Through the Art of Visualization    4.5  100 mil
# 7  Master the Art of Data Visualization With Tabl...    4.2     None
# 8                Create Geovisualizations in Tableau   None     None
# 9  Business Intelligence con la Product Suite di ...   None     None
#
#           level                                  university
# 0  Intermediate                    Coursera Project Network
# 1      Beginner                    Coursera Project Network
# ...

# %%
tableau3 = "https://www.coursera.org/search?query=tableau&page=3&index=prod_all_launched_products_term_optimization"
driver.get(tableau3)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

tableau3=pd.DataFrame()
tableau3['course'] =curso
tableau3['rating'] =rating
tableau3['students'] =students
tableau3['level'] =nivel
tableau3['university'] =universidad

tableau3
# Out:
#                                               course rating students  \
# 0  Introduction to Accounting Data Analytics and ...    4.8   20 mil
# 1                      Visual Analytics with Tableau    4.6   44 mil
# 2            Essential Design Principles for Tableau    4.4   48 mil
# 3               Create Interactive Graphs in Tableau   None     None
# 4        Building Stock Returns Heatmap with Tableau    4.6  2,5 mil
# 5         Analyze Digital Marketing Spend in Tableau      3     None
# 6                   Create a Story in Tableau Public    4.5     None
# 7   Tableau Public for Project Management and Beyond    4.3  4,1 mil
# 8     Tableau для рабочего процесса в анализе данных   None     None
# 9   Data Visualization: Analisi dei dati con Tableau   None     None
#
#           level                                  university
# 0      Beginner  University of Illinois at Urbana-Champaign
# 1      Beginner             University of California, Davis
# ...

# %%
tableau4 = "https://www.coursera.org/search?query=tableau&page=4&index=prod_all_launched_products_term_optimization"
driver.get(tableau4)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

tableau4=pd.DataFrame()
tableau4['course'] =curso
tableau4['rating'] =rating
tableau4['students'] =students
tableau4['level'] =nivel
tableau4['university'] =universidad

tableau4
# Out:
#                                               course rating students  \
# 0   Introduzione alla Data Visualization con Tableau   None     None
# 1  Google Data Studio - Création de Tableaux de B...    4.4  2,8 mil
# 2  Creating an Interactive Graph with Tableau Public    4.6     None
# 3           Building Candlestick Charts with Tableau    4.3  3,9 mil
# 4          How To Create A Sales Forecast In Tableau   None     None
# 5  Data Visualization e manipolazione dei dati co...   None     None
# 6             How to Create a Gantt Chart in Tableau   None     None
# 7     نظره عامة عن البيانات المصورة باستخدام Tableau   None     None
# 8          How to Visualize Research Data in Tableau   None     None
# 9  Increasing Real Estate Management Profits: Har...    4.7   13 mil
#
#           level                        university
# 0      Beginner  Università di Napoli Federico II
# 1  Intermediate          Coursera Project Network
# 2      Beginner          Coursera Project Network
# ...

# %%
tableau5 = "https://www.coursera.org/search?query=tableau&page=5&index=prod_all_launched_products_term_optimization"
driver.get(tableau5)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")
        
tableau5=pd.DataFrame()
tableau5['course'] =curso
tableau5['rating'] =rating
tableau5['students'] =students
tableau5['level'] =nivel
tableau5['university'] =universidad

tableau5
# Out:
#                                             course rating students  \
# 0              Foundations: Data, Data, Everywhere    4.8  710 mil
# 1                     Facebook Marketing Analytics    4.7   16 mil
# 2  Aspectos básicos: Datos, datos, en todas partes    4.5     None
# 3                   Introduction to Data Analytics    3.2  4,5 mil
# 4                         Statistics for Marketing    4.9  2,1 mil
# 5                  Data Analysis and Visualization    4.5  4,1 mil
# 6                 Grundlagen: Daten, überall Daten   None     None
# 7                Data Visualization Best Practices    4.6     None
# 8                                Data Storytelling   None     None
# 9                  Intro to TensorFlow en Français    3.3     None
#
#           level                        university
# 0      Beginner                            Google
# 1      Beginner                              Meta
# 2      Beginner                            Google
# ...

# %%
tableau6 = "https://www.coursera.org/search?query=tableau&page=6&index=prod_all_launched_products_term_optimization"
driver.get(tableau6)


curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

tableau6=pd.DataFrame()
tableau6['course'] =curso
tableau6['rating'] =rating
tableau6['students'] =students
tableau6['level'] =nivel
tableau6['university'] =universidad

tableau6
# Out:
#                                               course rating students  \
# 0  Compartir datos a través del arte de la visual...   None     None
# 1  Introduction à l'analyse de données à l'aide d...   None     None
# 2  Exploration et production de données pour les ...   None     None
# 3                         Ebola : Vaincre ensemble !    4.4  5,3 mil
# 4  Understanding Your Google Cloud Costs en Français   None     None
# 5  Choosing Which Method Is Best For Illustrating...   None     None
# 6  Scripting Bash - Découverte du Langage de Prog...    4.7     None
# 7                    Tout Pour Démarrer avec RStudio   None     None
# 8  Surveiller un hôte Linux avec Prometheus-Grafa...   None     None
# 9  Créer un ingress controller dans Kubernetes av...   None     None
#
#           level                                  university
# 0      Beginner                                      Google
# 1         Mixed                             Rice University
# ...

# %%
tableau7 = "https://www.coursera.org/search?query=tableau&page=7&index=prod_all_launched_products_term_optimization"
driver.get(tableau7)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

tableau7=pd.DataFrame()
tableau7['course'] =curso
tableau7['rating'] =rating
tableau7['students'] =students
tableau7['level'] =nivel
tableau7['university'] =universidad

tableau7
# Out:
#                                               course rating students  \
# 0  Créer un Reverse Proxy pour conteneurs Docker ...   None     None
# 1                       Quelques instructions en PHP   None     None
# 2     Tables Statistiques Pour la Publication dans R   None     None
# 3          Comment commencer avec Pinterest Shopping   None     None
# 4  Créer un site web Wordpress avec Amazon Lightsail   None     None
# 5                 Daten über Visualisierungen Teilen   None     None
# 6  Utilisation et gestion des pointeurs avec la P...   None     None
# 7  Intégrer des applications dans votre Dashboard...   None     None
# 8               Economie du sol et de l'immobilier I    4.7   14 mil
# 9  Compétences Excel pour l’entreprise : les noti...   None     None
#
#           level                                university
# 0  Intermediate                  Coursera Project Network
# 1      Beginner                  Coursera Project Network
# ...

# %%
tableaufinal = pd.concat([tableau1, tableau2, tableau3, tableau4, tableau5, tableau6, tableau7])

# %%
tableaufinal = tableaufinal.reset_index()

# %%
tableaufinal.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(70):
    lista.append("Tableau")

# %%
tableaufinal['skills'] = lista

# %%
tableaufinal
# Out:
#                                                course rating students  \
# 0                     Data Visualization with Tableau    4.5  170 mil
# 1                               Google Data Analytics    4.8  740 mil
# 2   Data Visualization and Communication with Tableau    4.7  190 mil
# 3    Excel to MySQL: Analytic Techniques for Business    4.6  660 mil
# 4              Анализ и визуализация данных в Tableau    4.8     None
# ..                                                ...    ...      ...
# 65  Créer un ingress controller dans Kubernetes av...   None     None
# 66  Créer un Reverse Proxy pour conteneurs Docker ...   None     None
# 67  Utilisation et gestion des pointeurs avec la P...   None     None
# 68  Scripting Bash - Découverte du Langage de Prog...    4.7     None
# 69                       Quelques instructions en PHP   None     None
#
#            level                                  university   skills
# ...

# %%
tableaufinal.to_csv("tableau.csv")

# %% [markdown]
# ### PYTHON COURSES

# %%
# Repito código porque escrapeo página por página. He escrapeado 50 páginas de Python (500 cursos).

# %%
python1 = "https://www.coursera.org/search?query=python&page=1&index=prod_all_launched_products_term_optimization"
driver.get(python1)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")
        
python1=pd.DataFrame()
python1['course'] =curso
python1['rating'] =rating
python1['students'] =students
python1['level'] =nivel
python1['university'] =universidad

python1
# Out:
#                                               course rating students  \
# 0                               Python for Everybody    4.8    2,7 m
# 1                   Google IT Automation with Python    4.7  600 mil
# 2                               Python 3 Programming    4.7  350 mil
# 3                             Crash Course on Python    4.8  520 mil
# 4      Data Science Fundamentals with Python and SQL    4.6  570 mil
# 5                   Applied Data Science with Python    4.5  800 mil
# 6  Programming for Everybody (Getting Started wit...    4.8    2,5 m
# 7          Python for Data Science, AI & Development    4.6  380 mil
# 8                                   IBM Data Science    4.6      1 m
# 9   Introduction to Programming with Python and Java    4.4   35 mil
#
#           level                  university
# 0      Beginner      University of Michigan
# 1      Beginner                      Google
# 2      Beginner      University of Michigan
# ...

# %%
python2 = "https://www.coursera.org/search?query=python&page=2&index=prod_all_launched_products_term_optimization"
driver.get(python2)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")
        
python2=pd.DataFrame()
python2['course'] =curso
python2['rating'] =rating
python2['students'] =students
python2['level'] =nivel
python2['university'] =universidad

python2
# Out:
#                                               course rating students  \
# 0                IBM DevOps and Software Engineering    4.6  470 mil
# 1            Bachelor of Science in Computer Science   None     None
# 2                         Программирование на Python    4.5   80 mil
# 3                                      Python Basics    4.8  300 mil
# 4                             Statistics with Python    4.6  110 mil
# 5                     Data Structures and Algorithms    4.6  550 mil
# 6                  Master of Science in Data Science   None     None
# 7                Introduction to Scripting in Python    4.7  110 mil
# 8                                   IBM Data Analyst    4.6  720 mil
# 9  Data Science Foundations: Data Structures and ...    4.6   12 mil
#
#           level                                  university
# 0      Beginner                                         IBM
# 1          None                        University of London
# ...

# %%
python3 = "https://www.coursera.org/search?query=python&page=3&index=prod_all_launched_products_term_optimization"
driver.get(python3)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python3=pd.DataFrame()
python3['course'] =curso
python3['rating'] =rating
python3['students'] =students
python3['level'] =nivel
python3['university'] =universidad

python3
# Out:
#                                               course rating students  \
# 0                               Django for Everybody    4.7   73 mil
# 1           Python for Data Analysis: Pandas & NumPy    4.4  3,9 mil
# 2  Master of Science in Machine Learning and Data...   None     None
# 3       Python and Statistics for Financial Analysis    4.4  120 mil
# 4                           Python for Cybersecurity    4.4  6,5 mil
# 5                        Python Scripting for DevOps    4.2  3,4 mil
# 6                 Introduction to Python Programming    4.4   24 mil
# 7      Master of Computer and Information Technology   None     None
# 8                             Introduction to Python    4.5   29 mil
# 9          Data Science for Investment Professionals    4.9  1,5 mil
#
#           level                                         university
# 0  Intermediate                             University of Michigan
# 1      Beginner                           Coursera Project Network
# ...

# %%
python4 = "https://www.coursera.org/search?query=python&page=4&index=prod_all_launched_products_term_optimization"
driver.get(python4)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python4=pd.DataFrame()
python4['course'] =curso
python4['rating'] =rating
python4['students'] =students
python4['level'] =nivel
python4['university'] =universidad

python4
# Out:
#                                               course rating students  \
# 0                     Advanced Data Science with IBM    4.3  110 mil
# 1  Introducción a la programación en Python I: Ap...    4.4  200 mil
# 2                                 IBM AI Engineering    4.6  300 mil
# 3                 Learn to Program: The Fundamentals    4.7  280 mil
# 4  Modern Application Development with Python on AWS    4.7  140 mil
# 5     Programming in Python: A Hands-on Introduction    4.5  5,2 mil
# 6      Python Data Products for Predictive Analytics    4.2   25 mil
# 7                             Python Data Structures    4.9  830 mil
# 8  Introdução à Ciência da Computação com Python ...    4.9  190 mil
# 9                             Programación en Python    4.7   12 mil
#
#           level                                university
# 0      Advanced                                       IBM
# 1      Beginner  Pontificia Universidad Católica de Chile
# ...

# %%
python5 = "https://www.coursera.org/search?query=python&page=5&index=prod_all_launched_products_term_optimization"
driver.get(python5)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python5=pd.DataFrame()
python5['course'] =curso
python5['rating'] =rating
python5['students'] =students
python5['level'] =nivel
python5['university'] =universidad

python5
# Out:
#                                               course rating students  \
# 0  Investment Management with Python and Machine ...    4.6   52 mil
# 1                          Advanced Machine Learning    4.4  350 mil
# 2                               IBM Data Engineering    4.6  500 mil
# 3                       Facebook Marketing Analytics    4.7   16 mil
# 4                                   Machine Learning    4.9    4,7 m
# 5                     Python Classes and Inheritance    4.7   75 mil
# 6               DeepLearning.AI TensorFlow Developer    4.7  330 mil
# 7                             Python Data Structures    4.4  8,4 mil
# 8     Databases and SQL for Data Science with Python    4.6  240 mil
# 9                    Python Project for Data Science    4.5   54 mil
#
#           level                university
# 0      Beginner     EDHEC Business School
# 1      Advanced            HSE University
# 2      Beginner                       IBM
# ...

# %%
python6 = "https://www.coursera.org/search?query=python&page=6&index=prod_all_launched_products_term_optimization"
driver.get(python6)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python6=pd.DataFrame()
python6['course'] =curso
python6['rating'] =rating
python6['students'] =students
python6['level'] =nivel
python6['university'] =universidad

python6
# Out:
#                                               course rating students  \
# 0                          Data Analysis with Python    4.7  230 mil
# 1                    Using Python to Access Web Data    4.8  550 mil
# 2             Introduction to Data Science in Python    4.5  660 mil
# 3  Using Python to Interact with the Operating Sy...    4.7  130 mil
# 4                     Data Visualization with Python    4.5  150 mil
# 5   Fundamentos de Ciencia de Datos con Python y SQL    4.3  4,6 mil
# 6  Introduction to Portfolio Construction and Ana...    4.8   44 mil
# 7                        Using Databases with Python    4.8  410 mil
# 8                     Aprende a programar con Python    4.5   49 mil
# 9  Foundations of Data Science: K-Means Clusterin...    4.7   27 mil
#
#           level              university
# 0      Beginner                     IBM
# 1         Mixed  University of Michigan
# 2  Intermediate  University of Michigan
# 3      Beginner                  Google
# ...

# %%
python7 = "https://www.coursera.org/search?query=python&page=7&index=prod_all_launched_products_term_optimization"
driver.get(python7)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python7=pd.DataFrame()
python7['course'] =curso
python7['rating'] =rating
python7['students'] =students
python7['level'] =nivel
python7['university'] =universidad

python7
# Out:
#                                               course rating students  \
# 0     Understanding and Visualizing Data with Python    4.7   97 mil
# 1                         Data Analysis Using Python    4.6  7,5 mil
# 2                    Python for Genomic Data Science    4.3   46 mil
# 3  用 Python 做商管程式設計（一）(Programming for Business C...    4.9   27 mil
# 4                Python Project for Data Engineering    4.6  9,3 mil
# 5  Capstone: Retrieving, Processing, and Visualiz...    4.7  220 mil
# 6   Exploratory Data Analysis With Python and Pandas    4.6  7,6 mil
# 7          Python Functions, Files, and Dictionaries    4.8   85 mil
# 8                 COVID19 Data Analysis Using Python    4.5   28 mil
# 9    Create Your First Web App with Python and Flask    4.5   13 mil
#
#           level                  university
# 0      Beginner      University of Michigan
# 1      Beginner  University of Pennsylvania
# 2         Mixed    Johns Hopkins University
# ...

# %%
python8 = "https://www.coursera.org/search?query=python&page=8&index=prod_all_launched_products_term_optimization"
driver.get(python8)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python8=pd.DataFrame()
python8['course'] =curso
python8['rating'] =rating
python8['students'] =students
python8['level'] =nivel
python8['university'] =universidad

python8
# Out:
#                                               course rating students  \
# 0  Design Computing: 3D Modeling in Rhinoceros wi...      5  8,5 mil
# 1       Inferential Statistical Analysis with Python    4.6   32 mil
# 2                   Practical Python for AI Coding 1    4.7  1,9 mil
# 3                      Python Programming Essentials    4.8   75 mil
# 4          Introducción a la programación con Python    4.6   39 mil
# 5  Create a Boggle Word Solver using recursion in...    4.4  2,8 mil
# 6                 Applied Machine Learning in Python    4.6  250 mil
# 7  Applied Plotting, Charting & Data Representati...    4.5  160 mil
# 8         Data Collection and Processing with Python    4.7   62 mil
# 9                            Game Theory with Python    4.3  6,6 mil
#
#           level                                         university
# 0         Mixed                             University of Michigan
# 1  Intermediate                             University of Michigan
# ...

# %%
python9 = "https://www.coursera.org/search?query=python&page=9&index=prod_all_launched_products_term_optimization"
driver.get(python9)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")
        
python9=pd.DataFrame()
python9['course'] =curso
python9['rating'] =rating
python9['students'] =students
python9['level'] =nivel
python9['university'] =universidad

python9
# Out:
#                                               course rating students  \
# 0  Advanced Portfolio Construction and Analysis w...    4.8   15 mil
# 1           用Python玩转数据 Data Processing Using Python    4.7   84 mil
# 2                       Data Processing Using Python    4.1   56 mil
# 3            COVID19 Data Visualization Using Python    4.6  3,3 mil
# 4  Build a Data Science Web App with Streamlit an...    4.6   14 mil
# 5   Python and Machine Learning for Asset Management    3.1   13 mil
# 6  Robot Localization with Python and Particle Fi...    4.4     None
# 7  Problem Solving, Python Programming, and Video...    4.2   36 mil
# 8                        Python Data Representations    4.7   21 mil
# 9  An Introduction to Interactive Programming in ...    4.8  200 mil
#
#           level                university
# 0  Intermediate     EDHEC Business School
# 1         Mixed        Nanjing University
# 2      Beginner        Nanjing University
# ...

# %%
python10 = "https://www.coursera.org/search?query=python&page=10&index=prod_all_launched_products_term_optimization"
driver.get(python10)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python10=pd.DataFrame()
python10['course'] =curso
python10['rating'] =rating
python10['students'] =students
python10['level'] =nivel
python10['university'] =universidad

python10
# Out:
#                                               course rating students  \
# 0      Python Project: pillow, tesseract, and opencv      4   53 mil
# 1  Sentimental Analysis on COVID-19 Tweets using ...    4.6     None
# 2           Introduction to Python for Cybersecurity    4.4  6,1 mil
# 3            Automating Real-World Tasks with Python    4.8   46 mil
# 4                               Python Data Analysis    4.7   33 mil
# 5     Create Your First Chatbot with Rasa and Python    4.5   17 mil
# 6  Build a Machine Learning Web App with Streamli...    4.7  9,9 mil
# 7  Create Interactive Dashboards with Streamlit a...    4.7  8,5 mil
# 8                      Python para Data Science y AI    4.8  2,1 mil
# 9  Create an interactive fiction adventure game w...    4.6    3 mil
#
#           level                university
# 0  Intermediate    University of Michigan
# 1  Intermediate  Coursera Project Network
# 2  Intermediate                   Infosec
# ...

# %%
python11 = "https://www.coursera.org/search?query=python&page=11&index=prod_all_launched_products_term_optimization"
driver.get(python11)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python11=pd.DataFrame()
python11['course'] =curso
python11['rating'] =rating
python11['students'] =students
python11['level'] =nivel
python11['university'] =universidad

python11
# Out:
#                                               course rating students  \
# 0         Using SAS Viya REST APIs with Python and R    4.6  3,1 mil
# 1   Concepts in Python: Loops, Functions and Returns    4.7  2,6 mil
# 2    Introduction to Customer Segmentation in Python    4.6     None
# 3  The Raspberry Pi Platform and Python Programmi...    4.7  110 mil
# 4        Advanced Python Scripting for Cybersecurity      4     None
# 5        Introduction to Python Scripting for DevOps    4.3  2,5 mil
# 6  用 Python 做商管程式設計（二）(Programming for Business C...    4.6  7,9 mil
# 7          Logistic Regression with Python and Numpy    4.5  5,7 mil
# 8            Linear Regression with NumPy and Python    4.4   16 mil
# 9  Python for Finance: Beta and Capital Asset Pri...    4.6     None
#
#           level                        university
# 0         Mixed                               SAS
# 1      Beginner          Coursera Project Network
# 2      Beginner          Coursera Project Network
# ...

# %%
python12 = "https://www.coursera.org/search?query=python&page=12&index=prod_all_launched_products_term_optimization"
driver.get(python12)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python12=pd.DataFrame()
python12['course'] =curso
python12['rating'] =rating
python12['students'] =students
python12['level'] =nivel
python12['university'] =universidad

python12
# Out:
#                                               course rating students  \
# 0              Accounting Data Analytics with Python    4.1  8,6 mil
# 1  Image Denoising Using AutoEncoders in Keras an...    4.5  6,6 mil
# 2            Create a Python Application using MySQL    4.5    5 mil
# 3  Python for Data Visualization: Matplotlib & Se...    4.7     None
# 4  Introduction to Data Science and scikit-learn ...    3.8     None
# 5                 Create Your First Game with Python    4.5   12 mil
# 6  Creating a Wordcloud using NLP and TF-IDF in P...   None     None
# 7                       Exception Handling in Python    4.7    2 mil
# 8         Crime Zone Heatmaps with Python and Folium   None     None
# 9               FIFA20 Data Exploration using Python    4.6  1,9 mil
#
#           level                                  university
# 0  Intermediate  University of Illinois at Urbana-Champaign
# 1  Intermediate                    Coursera Project Network
# ...

# %%
python13 = "https://www.coursera.org/search?query=python&page=13&index=prod_all_launched_products_term_optimization"
driver.get(python13)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python13=pd.DataFrame()
python13['course'] =curso
python13['rating'] =rating
python13['students'] =students
python13['level'] =nivel
python13['university'] =universidad

python13
# Out:
#                                               course rating students  \
# 0                        Processing Data with Python    4.4  5,7 mil
# 1   Python Scripting: Dates, Classes and Collections    4.4     None
# 2     GUI programming: Create a Calculator in Python    4.8     None
# 3      Neural Network Visualizer Web App with Python    4.5  6,5 mil
# 4  Clustering Geolocation Data Intelligently in P...    4.5   10 mil
# 5                 Basic Statistics in Python (ANOVA)    4.4     None
# 6  Build a Bot in Python for Basic File and Inter...   None     None
# 7    Support Vector Machine Classification in Python    4.4    6 mil
# 8      Version Control of a Python Project using Git    4.4  1,8 mil
# 9       Merge, Sort and Filter Data in Python Pandas    4.5  3,4 mil
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1      Beginner                LearnQuest
# 2  Intermediate  Coursera Project Network
# ...

# %%
python14 = "https://www.coursera.org/search?query=python&page=14&index=prod_all_launched_products_term_optimization"
driver.get(python14)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python14=pd.DataFrame()
python14['course'] =curso
python14['rating'] =rating
python14['students'] =students
python14['level'] =nivel
python14['university'] =universidad

python14
# Out:
#                                               course rating students  \
# 0  Language Classification with Naive Bayes in Py...    4.5  6,1 mil
# 1  Determine Shortest Paths Between Routers Using...    4.6     None
# 2  Data Analysis in Python with pandas & matplotl...    2.5     None
# 3  Python Scripting: Files, Inheritance, and Data...    4.7     None
# 4           Class Creation in Object Oriented Python    4.3  2,7 mil
# 5                     Data Visualization with Python    4.5  7,7 mil
# 6  Basic Statistics in Python (Correlations and T...    4.3     None
# 7     Aprendiendo Python con estadística descriptiva    4.7     None
# 8                    Creando simulaciones con python   None     None
# 9  Image Compression and Generation using Variati...    4.7  3,2 mil
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2      Beginner                     Codio
# ...

# %%
python15 = "https://www.coursera.org/search?query=python&page=15&index=prod_all_launched_products_term_optimization"
driver.get(python15)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python15=pd.DataFrame()
python15['course'] =curso
python15['rating'] =rating
python15['students'] =students
python15['level'] =nivel
python15['university'] =universidad

python15
# Out:
#                                               course rating students  \
# 0                          Python for Active Defense    4.4     None
# 1                     Estructuras de datos en Python    4.5   14 mil
# 2     Improve Your Python Code Using Amazon CodeGuru    4.6  2,1 mil
# 3  Reverse and complement nucleic acid sequences ...    4.4     None
# 4  Create Python Linux Script to Generate a Disk ...    4.5  4,4 mil
# 5  Regex Python - Découvrir les Expressions Régul...    4.8     None
# 6  Classification Trees in Python, From Start To ...    4.6    9 mil
# 7  Create a Memory Puzzle Game in Python Using Py...    4.3  1,7 mil
# 8               Big-O Time Complexity in Python Code    4.6     None
# 9                       Análisis de datos con Python    4.6  1,6 mil
#
#           level                university
# 0  Intermediate                   Infosec
# 1      Beginner       Universidad Austral
# 2  Intermediate       Amazon Web Services
# ...

# %%
python16 = "https://www.coursera.org/search?query=python&page=16&index=prod_all_launched_products_term_optimization"
driver.get(python16)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python16=pd.DataFrame()
python16['course'] =curso
python16['rating'] =rating
python16['students'] =students
python16['level'] =nivel
python16['university'] =universidad

python16
# Out:
#                                               course rating students  \
# 0      Python 101: Develop Your First Python Program    4.8  3,6 mil
# 1          Create Your First Python Program From UST    4.6   30 mil
# 2  An Introduction to Interactive Programming in ...    4.9   47 mil
# 3  Object-Oriented Python: Inheritance and Encaps...    4.3  2,1 mil
# 4        Programación Orientada a Objetos con Python      4   14 mil
# 5  Compose and Program Music in Python using Ears...    4.5   13 mil
# 6                Manejo de bases de datos con Python    4.2   13 mil
# 7  用 Python 做商管程式設計（三）(Programming for Business C...    4.9  5,9 mil
# 8             Uso de Python para Acceder a Datos Web   None     None
# 9             Python Basics: Selection and Iteration    4.6  2,8 mil
#
#           level                  university
# 0      Beginner    Coursera Project Network
# 1      Beginner    Coursera Project Network
# 2      Beginner             Rice University
# ...

# %%
python17 = "https://www.coursera.org/search?query=python&page=17&index=prod_all_launched_products_term_optimization"
driver.get(python17)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python17=pd.DataFrame()
python17['course'] =curso
python17['rating'] =rating
python17['students'] =students
python17['level'] =nivel
python17['university'] =universidad

python17
# Out:
#                                               course rating students  \
# 0  Global Warming II: Create Your Own Models in P...    4.1   13 mil
# 1  Python Basics: Create a Guessing Number Game f...    4.6  3,5 mil
# 2  Python Database Connection with MariaDB From I...    4.7  2,2 mil
# 3                Python para a Ciência de Dados e IA   None     None
# 4  Python Object Basics: Functions, Recursion, an...    4.8     None
# 5  Python Basic Structures: Lists, Strings, and F...    4.4     None
# 6  Database Operations in MariaDB Using Python Fr...    4.6  1,8 mil
# 7  Use Python Regular Expressions to Process File...    3.3     None
# 8  Where, Why, and How of Lambda Functions in Python   None     None
# 9                               Python에서 데이터베이스 사용하기   None     None
#
#           level                 university
# 0         Mixed  The University of Chicago
# 1      Beginner   Coursera Project Network
# 2  Intermediate   Coursera Project Network
# ...

# %%
python18 = "https://www.coursera.org/search?query=python&page=18&index=prod_all_launched_products_term_optimization"
driver.get(python18)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python18=pd.DataFrame()
python18['course'] =curso
python18['rating'] =rating
python18['students'] =students
python18['level'] =nivel
python18['university'] =universidad

python18
# Out:
#                                               course rating students  \
# 0                                Dice Game in Python    4.5     None
# 1             Python: обработка и анализ данных и ИИ   None     None
# 2            Statistical Analysis using Python Numpy   None     None
# 3                     Python Dynamic HTML Web Server    4.5    6 mil
# 4                    Работа с базами данных в Python   None     None
# 5               Визуализация данных с помощью Python   None     None
# 6                        Python Scripting for DevOps    4.3     None
# 7  Support Vector Machines in Python, From Start ...    4.6  4,6 mil
# 8     Analyze Box Office Data with Plotly and Python    4.5  8,5 mil
# 9  Snake game in Python: use Pygame to build your...   None     None
#
#           level                university
# 0      Beginner  Coursera Project Network
# 1      Beginner                       IBM
# 2  Intermediate  Coursera Project Network
# ...

# %%
python19 = "https://www.coursera.org/search?query=python&page=19&index=prod_all_launched_products_term_optimization"
driver.get(python19)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python19=pd.DataFrame()
python19['course'] =curso
python19['rating'] =rating
python19['students'] =students
python19['level'] =nivel
python19['university'] =universidad

python19
# Out:
#                                               course rating students  \
# 0              Aprendiendo Python con bases de datos    4.7     None
# 1                           Primeros pasos en Python    4.6     None
# 2  Create Beautiful Data Visualizations with Pyth...   None     None
# 3  Introduction to Search Techniques in Python: B...   None     None
# 4  Implementing Hangman Game Using Basics of Pyth...    4.5     None
# 5              Aprendiendo Python con álgebra lineal    4.6     None
# 6         Aprendiendo Python con circuitos digitales    4.8     None
# 7  Creating a Word Jumble Game in Python Using Tk...   None     None
# 8  Create a Connect Four Game in Python using Pygame   None     None
# 9                       Machine Learning with Python    4.7  250 mil
#
#           level                university
# 0      Beginner  Coursera Project Network
# 1      Beginner  Coursera Project Network
# 2  Intermediate  Coursera Project Network
# ...

# %%
python20 = "https://www.coursera.org/search?query=python&page=20&index=prod_all_launched_products_term_optimization"
driver.get(python20)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python20=pd.DataFrame()
python20['course'] =curso
python20['rating'] =rating
python20['students'] =students
python20['level'] =nivel
python20['university'] =universidad

python20
# Out:
#                                               course rating students  \
# 0            Statistics for Data Science with Python    4.6   12 mil
# 1         Building Modern Python Applications on AWS    4.5   73 mil
# 2                        Análise de dados com Python   None     None
# 3  Introdução à Ciência da Computação com Python ...    4.9   25 mil
# 4    Python Project for AI & Application Development    4.5  7,7 mil
# 5                        Data Science con Python e R    4.1     None
# 6    Programación para todos (Introducción a Python)    4.9  2,2 mil
# 7  Computers, Waves, Simulations: A Practical Int...    4.7   16 mil
# 8     Fitting Statistical Models to Data with Python    4.4   26 mil
# 9  Programmation pour tous (mise en route de Python)    4.9     None
#
#           level                                    university
# 0         Mixed                                           IBM
# 1  Intermediate                           Amazon Web Services
# ...

# %%
python21 = "https://www.coursera.org/search?query=python&page=21&index=prod_all_launched_products_term_optimization"
driver.get(python21)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python21=pd.DataFrame()
python21['course'] =curso
python21['rating'] =rating
python21['students'] =students
python21['level'] =nivel
python21['university'] =universidad

python21
# Out:
#                                               course rating students  \
# 0  Computer Vision - Image Basics with OpenCV and...    4.3   14 mil
# 1                      Applied Text Mining in Python    4.2  120 mil
# 2  Programação para todos (Conceitos básicos de P...      5     None
# 3                       Python: Istruzioni per l’uso    4.1     None
# 4  Geospatial Data Visualization using Python and...   None     None
# 5            Use Python Unit Test to Demonstrate TDD   None     None
# 6  Python and Machine-Learning for Asset Manageme...    4.4   11 mil
# 7          Applied Social Network Analysis in Python    4.7   85 mil
# 8                       Image Processing with Python    4.3   12 mil
# 9  Traffic Sign Classification Using Deep Learnin...    4.6   10 mil
#
#           level                        university
# 0      Beginner          Coursera Project Network
# 1  Intermediate            University of Michigan
# 2         Mixed            University of Michigan
# ...

# %%
python22 = "https://www.coursera.org/search?query=python&page=22&index=prod_all_launched_products_term_optimization"
driver.get(python22)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python22=pd.DataFrame()
python22['course'] =curso
python22['rating'] =rating
python22['students'] =students
python22['level'] =nivel
python22['university'] =universidad

python22
# Out:
#                                               course rating students  \
# 0  Climate Geospatial Analysis on Python with Xarray    4.2     None
# 1  Create a Python Application using PyMongo and ...    4.4  3,2 mil
# 2      Network Data Science with NetworkX and Python    4.3    5 mil
# 3          Машинное обучение с использованием Python   None     None
# 4  Dimensionality Reduction using an Autoencoder ...    4.6  3,3 mil
# 5  Activity Recognition using Python, Tensorflow ...   None     None
# 6                    Build a Python GUI with Tkinter    4.4  3,2 mil
# 7                  Aprendizado de máquina com Python   None     None
# 8                          Python Data Visualization    4.7   33 mil
# 9   Estadísticas para la Ciencia de Datos con Python   None     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2  Intermediate  Coursera Project Network
# ...

# %%
python23 = "https://www.coursera.org/search?query=python&page=23&index=prod_all_launched_products_term_optimization"
driver.get(python23)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python23=pd.DataFrame()
python23['course'] =curso
python23['rating'] =rating
python23['students'] =students
python23['level'] =nivel
python23['university'] =universidad

python23
# Out:
#                                               course rating students  \
# 0              Анализ данных с использованием Python   None     None
# 1                       Testing and Debugging Python    4.3  6,2 mil
# 2             Use Python to Create a Web Testing Bot      4     None
# 3     Analysing Covid-19 Geospatial data with Python    4.3     None
# 4  Procesamiento del lenguaje natural con Python ...      5     None
# 5            Extract Text Data with Python and Regex    4.4     None
# 6        Machine Learning for Accounting with Python    4.5  6,6 mil
# 7          Logistic Regression with NumPy and Python    4.5   12 mil
# 8  Image Segmentation with Python and Unsupervise...    4.6     None
# 9                   Advanced Python - Reconnaissance      4     None
#
#           level                                  university
# 0      Beginner                                         IBM
# 1  Intermediate                    Coursera Project Network
# ...

# %%
python24 = "https://www.coursera.org/search?query=python&page=24&index=prod_all_launched_products_term_optimization"
driver.get(python24)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python24=pd.DataFrame()
python24['course'] =curso
python24['rating'] =rating
python24['students'] =students
python24['level'] =nivel
python24['university'] =universidad

python24
# Out:
#                                               course rating students  \
# 0                  Aprendizaje Automático con Python      5     None
# 1                         Python per la Data Science   None     None
# 2  Visualizing & Communicating Results in Python ...   None     None
# 3                      Linear Regression with Python    4.6   10 mil
# 4  Análisis exploratorio de datos con Python y Pa...   None     None
# 5  Storing, Retrieving, and Processing JSON data ...   None     None
# 6       Wrangling Data for Data Analysts with Python   None     None
# 7                   Analyser vos données avec Python   None     None
# 8  Test Driven Development Process For Beginners ...   None     None
# 9  Where, Why, and How of List Comprehension in P...   None     None
#
#           level                        university
# 0  Intermediate                               IBM
# 1  Intermediate  Università di Napoli Federico II
# 2      Beginner                             Codio
# ...

# %%
python25 = "https://www.coursera.org/search?query=python&page=25&index=prod_all_launched_products_term_optimization"
driver.get(python25)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python25=pd.DataFrame()
python25['course'] =curso
python25['rating'] =rating
python25['students'] =students
python25['level'] =nivel
python25['university'] =universidad

python25
# Out:
#                                               course rating students  \
# 0  Facebook Network Analysis using Python and Net...    4.3     None
# 1         Visualización Avanzada de datos con Python   None     None
# 2             Regresión logística con NumPy y Python   None     None
# 3  Creating a Color Game in Python Using Tkinter GUI   None     None
# 4            Creating a Supermarket App Using Python    4.5     None
# 5  Python for Command-and-control, Exfiltration a...      5     None
# 6            DevOps and Build Automation with Python      4     None
# 7         Detect Fake News in Python with Tensorflow    3.8     None
# 8  COVID-19 : Les séries temporelles avec Python ...    4.5     None
# 9   Working with AWS S3 Buckets using Python & boto3      5     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2      Beginner  Coursera Project Network
# ...

# %%
python26 = "https://www.coursera.org/search?query=python&page=26&index=prod_all_launched_products_term_optimization"
driver.get(python26)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python26=pd.DataFrame()
python26['course'] =curso
python26['rating'] =rating
python26['students'] =students
python26['level'] =nivel
python26['university'] =universidad

python26
# Out:
#                                               course rating students  \
# 0               Introduction to Statistics in Python   None     None
# 1     DataViz - Grammaire des Graphiques avec Python   None     None
# 2       Text Generation with Markov Chains in Python   None     None
# 3  AWS Elastic Beanstalk:Deploy a Python(Flask) W...    4.6  1,5 mil
# 4                      Regular Expressions in Python    4.3     None
# 5  Configuring Python Extension Pack with Visual ...   None     None
# 6       Build a User Interface using Python Language   None     None
# 7                  Visualización de Datos con Python    4.6     None
# 8           Hypothesis Testing with Python and Excel    4.2  2,1 mil
# 9    Use Python and Java to Create a GUI Application   None     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2  Intermediate  Coursera Project Network
# ...

# %%
python27 = "https://www.coursera.org/search?query=python&page=27&index=prod_all_launched_products_term_optimization"
driver.get(python27)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python27=pd.DataFrame()
python27['course'] =curso
python27['rating'] =rating
python27['students'] =students
python27['level'] =nivel
python27['university'] =universidad

python27
# Out:
#                                               course rating students  \
# 0  Программирование для всех (начало работы с Pyt...   None     None
# 1  Create your own Sudoku Solver using AI and Python    4.3  2,7 mil
# 2                Create a Tic-Tac-Toe game in Python    4.9     None
# 3                   Practical Python for AI Coding 2   None     None
# 4                       Applied Calculus with Python   None     None
# 5                  Uso de bancos de dados com Python   None     None
# 6                   Uso de bases de datos con Python   None     None
# 7  Juniper Networks Automation Using Python and PyEZ   None     None
# 8                     Estructuras de datos de Python   None     None
# 9  Использование языка Python для доступа к веб-д...   None     None
#
#           level                                         university
# 0         Mixed                             University of Michigan
# 1  Intermediate                           Coursera Project Network
# ...

# %%
python28 = "https://www.coursera.org/search?query=python&page=28&index=prod_all_launched_products_term_optimization"
driver.get(python28)
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python28=pd.DataFrame()
python28['course'] =curso
python28['rating'] =rating
python28['students'] =students
python28['level'] =nivel
python28['university'] =universidad

python28
# Out:
#                                               course rating students  \
# 0                                   Defensive Python   None     None
# 1  Automatic Machine Learning with H2O AutoML and...    4.8  6,3 mil
# 2                         Estruturas de dados Python   None     None
# 3  Deploying a Python Data Analytics web app on H...    4.3     None
# 4    Analyze Box Office Data with Seaborn and Python    4.5  4,1 mil
# 5  Working with Amazon DynamoDB using Python & Boto3   None     None
# 6    Enhance your python unit testing using Coverage   None     None
# 7  Python Optical Character Recognition using Pyt...   None     None
# 8                            Структуры данных Python   None     None
# 9                 Visualização de dados com o Python   None     None
#
#           level                university
# 0         Mixed                   Infosec
# 1  Intermediate  Coursera Project Network
# 2         Mixed    University of Michigan
# ...

# %%
python29 = "https://www.coursera.org/search?query=python&page=29&index=prod_all_launched_products_term_optimization"
driver.get(python29)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python29=pd.DataFrame()
python29['course'] =curso
python29['rating'] =rating
python29['students'] =students
python29['level'] =nivel
python29['university'] =universidad

python29
# Out:
#                                               course rating students  \
# 0  Le Où, Pourquoi et Comment des Fonctions Lambd...   None     None
# 1             Series Temporales con Pycaret y Python   None     None
# 2           Data Processing using Python Collections   None     None
# 3   GUI Programming: Create a Login System in Python    3.8     None
# 4             Plots Creation using Matplotlib Python   None     None
# 5  Build a Machine Learning Image Classifier with...   None     None
# 6  ML: Diagnose the presence of Breast Cancer wit...   None     None
# 7  High-dimensional Data visualization techniques...   None     None
# 8                             Decryption with Python   None     None
# 9      Machine Learning con Python. Nivel intermedio   None     None
#
#           level                university
# 0      Beginner  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2  Intermediate  Coursera Project Network
# ...

# %%
python30 = "https://www.coursera.org/search?query=python&page=30&index=prod_all_launched_products_term_optimization"

driver.get(python30)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python30=pd.DataFrame()
python30['course'] =curso
python30['rating'] =rating
python30['students'] =students
python30['level'] =nivel
python30['university'] =universidad

python30
# Out:
#                                               course rating students  \
# 0  Installation et Configuration Python avec Visu...   None     None
# 1                   Nettoyer vos données avec Python   None     None
# 2                   Python استخدام قواعد البيانات مع   None     None
# 3  Write your own Python tool to footprint a web ...   None     None
# 4  Personal Desktop Notifier in Python: Covid-19 ...   None     None
# 5                                 Python بُنى بيانات   None     None
# 6  Exploring and Analyzing Fifa's Datasets Using ...   None     None
# 7  Crea tu primera aplicación web con Python y Flask   None     None
# 8  Python برنامج لحل لعبة السودوكو بالذكاء الاصطن...   None     None
# 9       Message Encoding/Decoding in Python with GUI   None     None
#
#           level                university
# 0      Beginner  Coursera Project Network
# 1      Beginner  Coursera Project Network
# 2         Mixed    University of Michigan
# ...

# %%
python31 = "https://www.coursera.org/search?query=python&page=31&index=prod_all_launched_products_term_optimization"

driver.get(python31)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python31=pd.DataFrame()
python31['course'] =curso
python31['rating'] =rating
python31['students'] =students
python31['level'] =nivel
python31['university'] =universidad

python31
# Out:
#                                               course rating students  \
# 0  Create Ping-Pong Game in Python using Turtle G...   None     None
# 1        Machine Learning con Python. Nivel Avanzado   None     None
# 2    Creating a Rock, Paper, Scissors Game in Python   None     None
# 3  Create a Dynamic-Link Library with DevC++ for ...   None     None
# 4  Design and Develop an Obstacles Game using Pyg...   None     None
# 5  Hierarchical relational data analysis using py...   None     None
# 6  برنامج تنبيه سطح المكتب باستخدام Python: إشعار...   None     None
# 7  Python في Pygame تصميم و تطوير لعبة العقبات با...   None     None
# 8                  Affectation de variable en Python   None     None
# 9                      Création de chaînes en Python   None     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2      Beginner  Coursera Project Network
# ...

# %%
python32 = "https://www.coursera.org/search?query=python&page=32&index=prod_all_launched_products_term_optimization"
driver.get(python32)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python32=pd.DataFrame()
python32['course'] =curso
python32['rating'] =rating
python32['students'] =students
python32['level'] =nivel
python32['university'] =universidad

python32
# Out:
#                                               course rating students  \
# 0  Tirer Parti des Listes Pour un Code Python Plu...   None     None
# 1  Aprendiendo Python con textos, números y ecuac...    4.8     None
# 2                              Graficando con Python   None     None
# 3       Chicken Invaders Game in Python using Pygame   None     None
# 4     أساسيات python: برمج لعبة تخمين الرقم من الصفر   None     None
# 5  بناء Neural Network مكونه من 3 طبقات بأستخدام ...   None     None
# 6               Les Expressions Régulières en Python   None     None
# 7      Python معالجة مسبقة للبيانات و تحليلها بواسطة   None     None
# 8      Crea tu primer juego de adivinanza con Python   None     None
# 9          MatplotLib Python باستخدام plots إنشاء ال   None     None
#
#           level                university
# 0      Beginner  Coursera Project Network
# 1      Beginner  Coursera Project Network
# 2  Intermediate  Coursera Project Network
# ...

# %%
python33 = "https://www.coursera.org/search?query=python&page=33&index=prod_all_launched_products_term_optimization"
driver.get(python33)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python33=pd.DataFrame()
python33['course'] =curso
python33['rating'] =rating
python33['students'] =students
python33['level'] =nivel
python33['university'] =universidad

python33
# Out:
#                                               course rating students  \
# 0                      Des nombres et plus en Python   None     None
# 1        Explorando funciones cuadráticas con Python   None     None
# 2  Aprendizaje automático con Python y Azure Note...   None     None
# 3  لعبة الثعبان عن طريق python:استخدم pygame لتصن...   None     None
# 4           Explorando funciones lineales con Python   None     None
# 5  Extraire des Données de Texte avec Python et R...   None     None
# 6             Python для информационной безопасности   None     None
# 7                       Python для кибербезопасности   None     None
# 8                       Introduction to Data Science    4.6  690 mil
# 9                               Applied Data Science    4.6  500 mil
#
#           level                   university
# 0      Beginner     Coursera Project Network
# 1      Beginner     Coursera Project Network
# 2      Beginner     Coursera Project Network
# ...

# %%
python34 = "https://www.coursera.org/search?query=python&page=34&index=prod_all_launched_products_term_optimization"
driver.get(python34)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python34=pd.DataFrame()
python34['course'] =curso
python34['rating'] =rating
python34['students'] =students
python34['level'] =nivel
python34['university'] =universidad

python34
# Out:
#                                               course rating students  \
# 0                     IBM Full Stack Cloud Developer    4.6  470 mil
# 1                          IBM Cybersecurity Analyst    4.6  250 mil
# 2                                     IBM Applied AI    4.6  530 mil
# 3                  Learn SQL Basics for Data Science    4.6  400 mil
# 4  Preparing for Google Cloud Certification: Mach...    4.6  350 mil
# 5                               IBM Machine Learning    4.6   37 mil
# 6                   Mathematics for Machine Learning    4.6  300 mil
# 7                       Sports Performance Analytics    4.5  8,9 mil
# 8         Computational Thinking for Problem Solving    4.7   75 mil
# 9                       Machine Learning for Trading    3.9   40 mil
#
#           level                       university
# 0      Beginner                              IBM
# 1      Beginner                              IBM
# 2      Beginner                              IBM
# ...

# %%
python35 = "https://www.coursera.org/search?query=python&page=35&index=prod_all_launched_products_term_optimization"
driver.get(python35)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python35=pd.DataFrame()
python35['course'] =curso
python35['rating'] =rating
python35['students'] =students
python35['level'] =nivel
python35['university'] =universidad

python35
# Out:
#                                               course rating students  \
# 0               Advanced Statistics for Data Science    4.4   94 mil
# 1                            Ciencia de Datos de IBM    4.5  7,4 mil
# 2                 Introducción a la Ciencia de Datos    4.5  4,4 mil
# 3                    Spacecraft Dynamics and Control    4.8   26 mil
# 4  Biology Meets Programming: Bioinformatics for ...    4.2  130 mil
# 5                   Data Analysis and Interpretation    4.4  140 mil
# 6                     Introduction to Data Analytics    3.2  4,5 mil
# 7                            Introduction to MongoDB    4.2   52 mil
# 8                  Getting started with TensorFlow 2    4.9   25 mil
# 9  Machine Learning Foundations: A Case Study App...    4.6  360 mil
#
#           level                          university
# 0      Advanced            Johns Hopkins University
# 1      Beginner                                 IBM
# ...

# %%
python36 = "https://www.coursera.org/search?query=python&page=36&index=prod_all_launched_products_term_optimization"
driver.get(python36)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python36=pd.DataFrame()
python36['course'] =curso
python36['rating'] =rating
python36['students'] =students
python36['level'] =nivel
python36['university'] =universidad

python36
# Out:
#                                               course rating students  \
# 0      Reinforcement Learning for Trading Strategies    3.7   11 mil
# 1  Mastering Data Analysis with Pandas: Learning ...    4.6     None
# 2  Developing Applications with SQL, Databases, a...    4.5  5,7 mil
# 3            Learn to Program: Crafting Quality Code    4.6   54 mil
# 4  Advanced Linear Models for Data Science 2: Sta...    4.5   20 mil
# 5       Computer Science: Programming with a Purpose    4.7  150 mil
# 6                Developing AI Applications on Azure    4.4   45 mil
# 7  Build & Deploy AI Messenger Chatbot using IBM ...    4.5  4,4 mil
# 8          Tweet Emotion Recognition with TensorFlow    4.7  4,3 mil
# 9  Agile Project: Product Prototype Touchpoint An...    4.6  2,1 mil
#
#           level                     university
# 0  Intermediate  New York Institute of Finance
# 1      Beginner       Coursera Project Network
# 2  Intermediate                            IBM
# ...

# %%
python37 = "https://www.coursera.org/search?query=python&page=37&index=prod_all_launched_products_term_optimization"
driver.get(python37)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python37=pd.DataFrame()
python37['course'] =curso
python37['rating'] =rating
python37['students'] =students
python37['level'] =nivel
python37['university'] =universidad

python37
# Out:
#                                               course rating students  \
# 0                          Data for Machine Learning    4.4  6,5 mil
# 1                              Data Science at Scale    4.2   83 mil
# 2  Principios de ingeniería de software automatiz...   None     None
# 3  Machine Learning for Analytics MasterTrack™ Ce...   None     None
# 4                                  Google IT Support    4.8    1,2 m
# 5  Modern Application Development with Node.js on...    4.8   83 mil
# 6       HTML, CSS, and Javascript for Web Developers    4.7  690 mil
# 7                Object Oriented Programming in Java    4.6  510 mil
# 8                    Introduction to Web Development    4.7  190 mil
# 9                           Machine Learning for All    4.7  110 mil
#
#           level                              university
# 0  Intermediate  Alberta Machine Intelligence Institute
# 1  Intermediate                University of Washington
# ...

# %%
python38 = "https://www.coursera.org/search?query=python&page=38&index=prod_all_launched_products_term_optimization"
driver.get(python38)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python38=pd.DataFrame()
python38['course'] =curso
python38['rating'] =rating
python38['students'] =students
python38['level'] =nivel
python38['university'] =universidad

python38
# Out:
#                                               course rating students  \
# 0                   Introduction to Machine Learning    4.7  160 mil
# 1  Advanced Django: Mastering Django and Django R...    4.8  1,8 mil
# 2  Introduction to Java and Object-Oriented Progr...    4.3  9,8 mil
# 3              Fundamentals of Scalable Data Science    4.3   63 mil
# 4            Web Application Technologies and Django    4.7   63 mil
# 5    Introduction to Trading, Machine Learning & GCP      4   32 mil
# 6    Advanced Machine Learning and Signal Processing    4.5   39 mil
# 7                Building Web Applications in Django    4.7   31 mil
# 8         Guided Tour of Machine Learning in Finance    3.8   28 mil
# 9      Using Machine Learning in Trading and Finance      4   16 mil
#
#           level                     university
# 0  Intermediate                Duke University
# 1      Advanced                          Codio
# 2      Beginner     University of Pennsylvania
# ...

# %%
python39 = "https://www.coursera.org/search?query=python&page=39&index=prod_all_launched_products_term_optimization"
driver.get(python39)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python39=pd.DataFrame()
python39['course'] =curso
python39['rating'] =rating
python39['students'] =students
python39['level'] =nivel
python39['university'] =universidad

python39
# Out:
#                                               course rating students  \
# 0  Introduction to Accounting Data Analytics and ...    4.8   20 mil
# 1                   Advanced Django: Building a Blog    4.9     None
# 2               Object-Oriented Programming Concepts    4.6  1,5 mil
# 3          Cloud Virtualization, Containers and APIs    4.4  2,5 mil
# 4  Statistics for Machine Learning for Investment...   None     None
# 5                             Cloud Data Engineering    4.2  2,4 mil
# 6  Advanced Django: Introduction to Django Rest F...    4.4     None
# 7              بايثون لعلوم البيانات والذكاء الصناعي   None     None
# 8                          Exploratory Data Analysis    4.2  5,2 mil
# 9  Build Your First Android App (Project-Centered...    4.2  330 mil
#
#           level                                  university
# 0      Beginner  University of Illinois at Urbana-Champaign
# 1      Advanced                                       Codio
# ...

# %%
python40 = "https://www.coursera.org/search?query=python&page=40&index=prod_all_launched_products_term_optimization"
driver.get(python40)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python40=pd.DataFrame()
python40['course'] =curso
python40['rating'] =rating
python40['students'] =students
python40['level'] =nivel
python40['university'] =universidad

python40
# Out:
#                                               course rating students  \
# 0          The Fundamental of Data-Driven Investment   None     None
# 1                Introduction to Bayesian Statistics    3.2  2,1 mil
# 2    Advanced Django: Advanced Django Rest Framework   None     None
# 3  Deploy an NLP Text Generator: Bart Simpson Cha...   None     None
# 4    Advanced Django: External APIs and Task Queuing   None     None
# 5                  التعلّم الآلي باستخدام لغة بايثون   None     None
# 6         Build a Classification Model using PyCaret   None     None
# 7                                      Deep Learning    4.8    1,2 m
# 8                       Data Engineering Foundations    4.6  490 mil
# 9                        IBM Data Warehouse Engineer    4.6  270 mil
#
#           level                university
# 0      Beginner   Sungkyunkwan University
# 1      Beginner                Databricks
# 2      Advanced                     Codio
# ...

# %%
python41 = "https://www.coursera.org/search?query=python&page=41&index=prod_all_launched_products_term_optimization"
driver.get(python41)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python41=pd.DataFrame()
python41['course'] =curso
python41['rating'] =rating
python41['students'] =students
python41['level'] =nivel
python41['university'] =universidad

python41
# Out:
#                                               course rating students  \
# 0  BI Foundations with SQL, ETL and Data Warehousing    4.6  250 mil
# 1                        Natural Language Processing    4.6  110 mil
# 2  Preparing for Google Cloud Certification: Clou...    4.6  250 mil
# 3  Data Engineering, Big Data, and Machine Learni...    4.6  250 mil
# 4                               Genomic Data Science    4.5  120 mil
# 5                      Security Analyst Fundamentals    4.6   36 mil
# 6                  Neural Networks and Deep Learning    4.9      1 m
# 7               IBM Introduction to Machine Learning    4.6   32 mil
# 8             Generative Adversarial Networks (GANs)    4.7   40 mil
# 9                    TensorFlow: Advanced Techniques    4.8   27 mil
#
#           level                university
# 0      Beginner                       IBM
# 1  Intermediate           DeepLearning.AI
# 2  Intermediate              Google Cloud
# ...

# %%
python42 = "https://www.coursera.org/search?query=python&page=42&index=prod_all_launched_products_term_optimization"
driver.get(python42)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python42=pd.DataFrame()
python42['course'] =curso
python42['rating'] =rating
python42['students'] =students
python42['level'] =nivel
python42['university'] =universidad

python42
# Out:
#                                               course rating students  \
# 0                                  Self-Driving Cars    4.7  130 mil
# 1             NoSQL, Big Data, and Spark Foundations    4.3   11 mil
# 2                             Practical Data Science    4.5   16 mil
# 3                             Tools for Data Science    4.5  260 mil
# 4  Introduction to Discrete Mathematics for Compu...    4.5  160 mil
# 5  Improving Deep Neural Networks: Hyperparameter...    4.9  440 mil
# 6   Machine Learning with TensorFlow on Google Cloud    4.5  120 mil
# 7                                    AI for Medicine    4.7   53 mil
# 8                  Машинное обучение и анализ данных    4.7  110 mil
# 9  Introduction to TensorFlow for Artificial Inte...    4.7  280 mil
#
#           level                                  university
# 0      Advanced                       University of Toronto
# 1      Beginner                                         IBM
# ...

# %%
python43 = "https://www.coursera.org/search?query=python&page=43&index=prod_all_launched_products_term_optimization"
driver.get(python43)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python43=pd.DataFrame()
python43['course'] =curso
python43['rating'] =rating
python43['students'] =students
python43['level'] =nivel
python43['university'] =universidad

python43
# Out:
#                                               course rating students  \
# 0                                           Big Data    4.5  340 mil
# 1                      Convolutional Neural Networks    4.9  400 mil
# 2                           PostgreSQL for Everybody    4.8   15 mil
# 3         Become a Sustainable Business Change Agent    4.7   13 mil
# 4  An Introduction to Programming the Internet of...    4.7  440 mil
# 5        Convolutional Neural Networks in TensorFlow    4.7  110 mil
# 6  Build Basic Generative Adversarial Networks (G...    4.7   38 mil
# 7  Microsoft Azure Data Scientist Associate - DP-...    4.6  3,2 mil
# 8          Advanced Machine Learning on Google Cloud    4.4   69 mil
# 9                           Analista de Datos de IBM    4.4   11 mil
#
#           level                          university
# 0      Beginner  University of California San Diego
# 1  Intermediate                     DeepLearning.AI
# ...

# %%
python44 = "https://www.coursera.org/search?query=python&page=44&index=prod_all_launched_products_term_optimization"
driver.get(python44)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python44=pd.DataFrame()
python44['course'] =curso
python44['rating'] =rating
python44['students'] =students
python44['level'] =nivel
python44['university'] =universidad

python44
# Out:
#                                               course rating students  \
# 0                                   Machine Learning    4.6  430 mil
# 1  Modern Robotics: Mechanics, Planning, and Control    4.7   44 mil
# 2          Natural Language Processing in TensorFlow    4.6  100 mil
# 3                    TensorFlow: Data and Deployment    4.6   40 mil
# 4   Mathematics for Machine Learning: Linear Algebra    4.7  280 mil
# 5                     TensorFlow 2 for Deep Learning    4.9   30 mil
# 6              Sequences, Time Series and Prediction    4.7   91 mil
# 7  Data Engineering, Big Data and ML on Google Cl...    4.5  4,7 mil
# 8  Analyze Datasets and Train ML Models using AutoML    4.5   14 mil
# 9                                            程序设计与算法    4.8   93 mil
#
#           level                university
# 0  Intermediate  University of Washington
# 1  Intermediate   Northwestern University
# 2  Intermediate           DeepLearning.AI
# ...

# %%
python45 = "https://www.coursera.org/search?query=python&page=45&index=prod_all_launched_products_term_optimization"
driver.get(python45)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python45=pd.DataFrame()
python45['course'] =curso
python45['rating'] =rating
python45['students'] =students
python45['level'] =nivel
python45['university'] =universidad

python45
# Out:
#                                               course rating students  \
# 0                Mastering Software Development in R    4.3   69 mil
# 1  Machine Learning and Reinforcement Learning in...    3.7   41 mil
# 2  Natural Language Processing with Probabilistic...    4.7   43 mil
# 3     Exploratory Data Analysis for Machine Learning    4.6   28 mil
# 4     Машинное обучение: от статистики до нейросетей    4.4  6,1 mil
# 5                         IBM AI Enterprise Workflow    4.3  9,7 mil
# 6                      Математика для анализа данных    4.4  4,9 mil
# 7                       Mathematics for Data Science    4.4   67 mil
# 8                          Fundamentals of Computing    4.8  250 mil
# 9  Penetration Testing, Incident Response and For...    4.6   30 mil
#
#           level                university
# 0      Beginner  Johns Hopkins University
# 1  Intermediate       New York University
# 2  Intermediate           DeepLearning.AI
# ...

# %%
python46 = "https://www.coursera.org/search?query=python&page=46&index=prod_all_launched_products_term_optimization"
driver.get(python46)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python46=pd.DataFrame()
python46['course'] =curso
python46['rating'] =rating
python46['students'] =students
python46['level'] =nivel
python46['university'] =universidad

python46
# Out:
#                                               course rating students  \
# 0  Custom Models, Layers, and Loss Functions with...    4.9   17 mil
# 1   Natural Language Processing with Sequence Models    4.5   37 mil
# 2                          Accounting Data Analytics    4.7   29 mil
# 3           Advanced Computer Vision with TensorFlow    4.8   16 mil
# 4                                         Psicología    4.8   24 mil
# 5                     Analítica de Datos en Finanzas    4.9     None
# 6                         Computational Neuroscience    4.6   95 mil
# 7                         AI for Scientific Research    3.3  1,7 mil
# 8    Custom and Distributed Training with TensorFlow    4.8  9,1 mil
# 9           Serverless Data Processing with Dataflow    4.1  3,8 mil
#
#           level                                  university
# 0  Intermediate                             DeepLearning.AI
# 1  Intermediate                             DeepLearning.AI
# ...

# %%
python47 = "https://www.coursera.org/search?query=python&page=47&index=prod_all_launched_products_term_optimization"
driver.get(python47)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python47=pd.DataFrame()
python47['course'] =curso
python47['rating'] =rating
python47['students'] =students
python47['level'] =nivel
python47['university'] =universidad

python47
# Out:
#                                               course rating students  \
# 0                              Data-driven Astronomy    4.8   26 mil
# 1                          Ciencia de Datos Aplicada    4.6  3,5 mil
# 2     Introduction to Big Data with Spark and Hadoop    4.4  6,5 mil
# 3                           AI for Medical Prognosis    4.7   19 mil
# 4                  Deep Neural Networks with PyTorch    4.4   32 mil
# 5  Foundations of Sports Analytics: Data, Represe...    4.5  7,4 mil
# 6  Introduction to Deep Learning & Neural Network...    4.7   23 mil
# 7        Bases de Inteligencia Artificial para Todos    4.7    8 mil
# 8  Mental Health and Resilience for Healthcare Wo...    4.8  3,6 mil
# 9                 Machine Learning for Supply Chains    3.3  1,7 mil
#
#           level                university
# 0  Intermediate  The University of Sydney
# 1      Beginner                       IBM
# 2      Beginner                       IBM
# ...

# %%
python48 = "https://www.coursera.org/search?query=python&page=48&index=prod_all_launched_products_term_optimization"
driver.get(python48)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python48=pd.DataFrame()
python48['course'] =curso
python48['rating'] =rating
python48['students'] =students
python48['level'] =nivel
python48['university'] =universidad

python48
# Out:
#                                               course rating students  \
# 0                      Algorithms for DNA Sequencing    4.7   32 mil
# 1   Sentiment Analysis with Deep Learning using BERT    4.5   12 mil
# 2   Hands-on Machine Learning with Google Cloud Labs    3.8    3 mil
# 3                   SAS Statistical Business Analyst    4.6    6 mil
# 4  State Estimation and Localization for Self-Dri...    4.7   38 mil
# 5  Data Science in Stratified Healthcare and Prec...    4.6   17 mil
# 6                  IBM Data Analyst Capstone Project    4.6   14 mil
# 7           Generative Deep Learning with TensorFlow    4.8  7,3 mil
# 8  Detecting COVID-19 with Chest X-Ray using PyTorch    4.5  9,9 mil
# 9  Data Engineer, Big Data and ML on Google Cloud...    4.4  2,3 mil
#
#           level                   university
# 0         Mixed     Johns Hopkins University
# 1  Intermediate     Coursera Project Network
# 2  Intermediate                 Google Cloud
# ...

# %%
python49 = "https://www.coursera.org/search?query=python&page=49&index=prod_all_launched_products_term_optimization"
driver.get(python49)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python49=pd.DataFrame()
python49['course'] =curso
python49['rating'] =rating
python49['students'] =students
python49['level'] =nivel
python49['university'] =universidad

python49
# Out:
#                                               course rating students  \
# 0  Data Science and Analysis Tools - from Jupyter...    3.2  3,4 mil
# 1   Kinematics: Describing the Motions of Spacecraft    4.9   19 mil
# 2       Data Analytics Foundations for Accountancy I    4.1  7,4 mil
# 3  Machine Learning with TensorFlow on Google Clo...    4.6  9,6 mil
# 4  Modern Robotics, Course 1: Foundations of Robo...    4.7   39 mil
# 5                                   Ciencia de datos    4.5     None
# 6  Data and Statistics Foundation for Investment ...    4.8     None
# 7              SQL for Data Science Capstone Project    4.2   20 mil
# 8                      Django Features and Libraries    4.8   18 mil
# 9                  More on Change and Sustainability    4.8  3,9 mil
#
#           level                                  university
# 0      Beginner                                       Codio
# 1      Advanced              University of Colorado Boulder
# ...

# %%
python50 = "https://www.coursera.org/search?query=python&page=50&index=prod_all_launched_products_term_optimization"
driver.get(python50)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

python50=pd.DataFrame()
python50['course'] =curso
python50['rating'] =rating
python50['students'] =students
python50['level'] =nivel
python50['university'] =universidad

python50
# Out:
#                                               course rating students  \
# 0            Browser-based Models with TensorFlow.js    4.7   32 mil
# 1           Facial Expression Recognition with Keras    4.5   21 mil
# 2                        Data Analysis Using Pyspark    4.4    7 mil
# 3                       Applied AI with DeepLearning    4.4   48 mil
# 4       Simulation and modeling of natural processes    4.2   32 mil
# 5  Data Engineering and Machine Learning using Spark    3.6  3,1 mil
# 6                                         파이썬 단기집중과정    4.8     None
# 7  Create Machine Learning Models in Microsoft Azure    4.7  2,3 mil
# 8  Deploy Machine Learning Model into AWS Cloud S...    4.3     None
# 9                      The R Programming Environment    4.3   48 mil
#
#           level                university
# 0  Intermediate           DeepLearning.AI
# 1  Intermediate  Coursera Project Network
# 2  Intermediate  Coursera Project Network
# ...

# %%
pythonfinal = pd.concat([python1, python2, python3, python4, python5, python6, python7, python8, python9, python10, python11, python12, python13, python14, python15, python16, python17, python18, python19, python20, python21, python22, python23, python24, python25, python26, python27, python28, python29, python30, python31, python32, python33, python34, python35, python36, python37, python38, python39, python40, python41, python42, python43, python44, python45, python46, python47, python48, python49, python50])

# %%
pythonfinal = pythonfinal.reset_index()

# %%
pythonfinal.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(500):
    lista.append("Python")

# %%
pythonfinal['skills'] = lista

# %%
pythonfinal
# Out:
#                                                 course rating students  \
# 0                                 Python for Everybody    4.8    2,7 m
# 1                     Google IT Automation with Python    4.7  600 mil
# 2                                 Python 3 Programming    4.7  350 mil
# 3                               Crash Course on Python    4.8  520 mil
# 4        Data Science Fundamentals with Python and SQL    4.6  570 mil
# ..                                                 ...    ...      ...
# 495  Data Engineering and Machine Learning using Spark    3.6  3,1 mil
# 496                                         파이썬 단기집중과정    4.8     None
# 497  Create Machine Learning Models in Microsoft Azure    4.7  2,3 mil
# 498  Deploy Machine Learning Model into AWS Cloud S...    4.3     None
# 499                      The R Programming Environment    4.3   48 mil
#
#             level                university  skills
# 0        Beginner    University of Michigan  Python
# ...

# %%
pythonfinal.to_csv("python.csv")

# %% [markdown]
# ### MACHINE LEARNING COURSES

# %%
# Repito código porque escrapeo página por página. He escrapeado 50 páginas de Machine LEarning (500 cursos).

# %%
ml1 = "https://www.coursera.org/search?query=machine%20learning&page=1&index=prod_all_launched_products_term_optimization"
driver.get(ml1)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml1=pd.DataFrame()
ml1['course'] =curso
ml1['rating'] =rating
ml1['students'] =students
ml1['level'] =nivel
ml1['university'] =universidad

ml1
# Out:
#                                               course rating students  \
# 0                                   Machine Learning    4.9    4,7 m
# 1                               IBM Machine Learning    4.6   37 mil
# 2                                   Machine Learning    4.6  430 mil
# 3                                      Deep Learning    4.8    1,2 m
# 4                   Mathematics for Machine Learning    4.6  300 mil
# 5                           Machine Learning for All    4.7  110 mil
# 6                   Applied Data Science with Python    4.5  800 mil
# 7  Machine Learning Engineering for Production (M...    4.7   47 mil
# 8                          Advanced Machine Learning    4.4  350 mil
# 9                              Google Data Analytics    4.8  740 mil
#
#           level                university
# 0         Mixed       Stanford University
# 1  Intermediate                       IBM
# 2  Intermediate  University of Washington
# ...

# %%
ml2 = "https://www.coursera.org/search?query=machine%20learning&page=2&index=prod_all_launched_products_term_optimization"
driver.get(ml2)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml2=pd.DataFrame()
ml2['course'] =curso
ml2['rating'] =rating
ml2['students'] =students
ml2['level'] =nivel
ml2['university'] =universidad

ml2
# Out:
#                                               course rating students  \
# 0                       Deep Learning for Healthcare   None     None
# 1  Introduction to Machine Learning: Supervised L...   None     None
# 2                                   IBM Data Science    4.6      1 m
# 3  Preparing for Google Cloud Certification: Mach...    4.6  350 mil
# 4               IBM Introduction to Machine Learning    4.6   32 mil
# 5                                       Data Science    4.5    1,2 m
# 6          Advanced Machine Learning on Google Cloud    4.4   69 mil
# 7               DeepLearning.AI TensorFlow Developer    4.7  330 mil
# 8                                 IBM AI Engineering    4.6  300 mil
# 9             Generative Adversarial Networks (GANs)    4.7   40 mil
#
#           level                                  university
# 0      Advanced  University of Illinois at Urbana-Champaign
# 1  Intermediate              University of Colorado Boulder
# ...

# %%
ml3 = "https://www.coursera.org/search?query=machine%20learning&page=3&index=prod_all_launched_products_term_optimization"
driver.get(ml3)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml3=pd.DataFrame()
ml3['course'] =curso
ml3['rating'] =rating
ml3['students'] =students
ml3['level'] =nivel
ml3['university'] =universidad

ml3
# Out:
#                                               course rating students  \
# 0                              AI Product Management    4.5  4,9 mil
# 1            Bachelor of Science in Computer Science   None     None
# 2  Machine Learning for Telecom Customers Churn P...    4.5     None
# 3                                   IBM Data Analyst    4.6  720 mil
# 4                 Applied Machine Learning in Python    4.6  250 mil
# 5  Unsupervised Machine Learning for Customer Mar...    4.8  9,8 mil
# 6                   Introduction to Machine Learning    4.7  160 mil
# 7                       Machine Learning with Python    4.7  250 mil
# 8  Post Graduate Certificate in Advanced Machine ...   None     None
# 9          Fake News Detection with Machine Learning    4.6  8,8 mil
#
#           level                university
# 0      Beginner           Duke University
# 1          None      University of London
# 2      Beginner  Coursera Project Network
# ...

# %%
ml4 = "https://www.coursera.org/search?query=machine%20learning&page=4&index=prod_all_launched_products_term_optimization"
driver.get(ml4)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml4=pd.DataFrame()
ml4['course'] =curso
ml4['rating'] =rating
ml4['students'] =students
ml4['level'] =nivel
ml4['university'] =universidad

ml4
# Out:
#                                               course rating students  \
# 0      Master of Computer and Information Technology   None     None
# 1               Google Cloud Digital Leader Training    4.8   37 mil
# 2                First Principles of Computer Vision    4.8    3 mil
# 3  Introduction to Machine Learning: Language Pro...    3.9  2,8 mil
# 4    Breast Cancer Prediction Using Machine Learning    4.3     None
# 5                         Introduction to Statistics    4.6  100 mil
# 6                   Google IT Automation with Python    4.7  600 mil
# 7                  Машинное обучение и анализ данных    4.7  110 mil
# 8                             Reinforcement Learning    4.7   64 mil
# 9                 Practical Data Science with MATLAB    4.7   39 mil
#
#           level                                  university
# 0          None                  University of Pennsylvania
# 1      Beginner                                Google Cloud
# ...

# %%
ml5 = "https://www.coursera.org/search?query=machine%20learning&page=5&index=prod_all_launched_products_term_optimization"
driver.get(ml5)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml5=pd.DataFrame()
ml5['course'] =curso
ml5['rating'] =rating
ml5['students'] =students
ml5['level'] =nivel
ml5['university'] =universidad

ml5
# Out:
#                                               course rating students  \
# 0                   SAS Statistical Business Analyst    4.6    6 mil
# 1                       Mathematics for Data Science    4.4   67 mil
# 2                               Python 3 Programming    4.7  350 mil
# 3                       Facebook Marketing Analytics    4.7   16 mil
# 4                              Data Science at Scale    4.2   83 mil
# 5  Introduction to TensorFlow for Artificial Inte...    4.7  280 mil
# 6   Hands-on Machine Learning with Google Cloud Labs    3.8    3 mil
# 7  Hands-on Foundations for Data Science and Mach...    4.3  4,6 mil
# 8                             Executive Data Science    4.5  230 mil
# 9  Data Engineering, Big Data, and Machine Learni...    4.6  250 mil
#
#           level                university
# 0  Intermediate                       SAS
# 1      Beginner            HSE University
# 2      Beginner    University of Michigan
# ...

# %%
ml6 = "https://www.coursera.org/search?query=machine%20learning&page=6&index=prod_all_launched_products_term_optimization"
driver.get(ml6)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml6=pd.DataFrame()
ml6['course'] =curso
ml6['rating'] =rating
ml6['students'] =students
ml6['level'] =nivel
ml6['university'] =universidad

ml6
# Out:
#                                               course rating students  \
# 0     Introduction to Machine Learning in Production    4.8   44 mil
# 1  Investment Management with Python and Machine ...    4.6   52 mil
# 2   Machine Learning with TensorFlow on Google Cloud    4.5  120 mil
# 3      Data Science: Statistics and Machine Learning    4.4  290 mil
# 4              Structuring Machine Learning Projects    4.8  370 mil
# 5      Machine Learning Data Lifecycle in Production    4.4   17 mil
# 6                       Machine Learning for Trading    3.9   40 mil
# 7   Mathematics for Machine Learning: Linear Algebra    4.7  280 mil
# 8  Google Cloud Big Data and Machine Learning Fun...    4.7  240 mil
# 9  Machine Learning and Reinforcement Learning in...    3.7   41 mil
#
#           level                     university
# 0      Advanced                DeepLearning.AI
# 1      Beginner          EDHEC Business School
# 2  Intermediate                   Google Cloud
# ...

# %%
ml7 = "https://www.coursera.org/search?query=machine%20learning&page=7&index=prod_all_launched_products_term_optimization"
driver.get(ml7)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml7=pd.DataFrame()
ml7['course'] =curso
ml7['rating'] =rating
ml7['students'] =students
ml7['level'] =nivel
ml7['university'] =universidad

ml7
# Out:
#                                               course rating students  \
# 0  Machine Learning Modeling Pipelines in Production    4.5   11 mil
# 1     Exploratory Data Analysis for Machine Learning    4.6   28 mil
# 2  Machine Learning Foundations for Product Managers    4.6  4,2 mil
# 3  Machine Learning Rock Star – the End-to-End Pr...    4.8   11 mil
# 4    Deploying Machine Learning Models in Production    4.6  9,2 mil
# 5    Fundamentals of Machine Learning for Healthcare    4.8  9,5 mil
# 6          Getting Started with AWS Machine Learning    4.5  190 mil
# 7  Mathematics for Machine Learning: Multivariate...    4.7  100 mil
# 8            Supervised Machine Learning: Regression    4.7  9,8 mil
# 9          Introduction to Embedded Machine Learning    4.8   15 mil
#
#           level               university
# 0      Advanced          DeepLearning.AI
# 1  Intermediate                      IBM
# 2      Beginner          Duke University
# ...

# %%
ml8 = "https://www.coursera.org/search?query=machine%20learning&page=8&index=prod_all_launched_products_term_optimization"
driver.get(ml8)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml8=pd.DataFrame()
ml8['course'] =curso
ml8['rating'] =rating
ml8['students'] =students
ml8['level'] =nivel
ml8['university'] =universidad

ml8
# Out:
#                                               course rating students  \
# 0                 Machine Learning for Supply Chains    3.3  1,7 mil
# 1  The Power of Machine Learning: Boost Business,...    4.8  9,2 mil
# 2    Introduction to Trading, Machine Learning & GCP      4   32 mil
# 3     Computer Vision with Embedded Machine Learning    4.7    4 mil
# 4  Scalable Machine Learning on Big Data using Ap...    3.8   20 mil
# 5    Advanced Machine Learning and Signal Processing    4.5   39 mil
# 6  機器學習基石上 (Machine Learning Foundations)---Mathe...    4.9   40 mil
# 7  Machine Learning with TensorFlow on Google Clo...    4.1  1,8 mil
# 8        Supervised Machine Learning: Classification    4.9  7,8 mil
# 9  Machine Learning Foundations: A Case Study App...    4.6  360 mil
#
#           level                  university
# 0  Intermediate                  LearnQuest
# 1      Beginner                         SAS
# 2  Intermediate                Google Cloud
# ...

# %%
ml9 = "https://www.coursera.org/search?query=machine%20learning&page=9&index=prod_all_launched_products_term_optimization"
driver.get(ml9)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml9=pd.DataFrame()
ml9['course'] =curso
ml9['rating'] =rating
ml9['students'] =students
ml9['level'] =nivel
ml9['university'] =universidad

ml9
# Out:
#                                               course rating students  \
# 0   Smart Analytics, Machine Learning, and AI on GCP    4.6   26 mil
# 1                   How Google does Machine Learning    4.6  110 mil
# 2              Mathematics for Machine Learning: PCA      4   65 mil
# 3  Machine Learning with TensorFlow on Google Clo...    4.6  9,6 mil
# 4         Guided Tour of Machine Learning in Finance    3.8   28 mil
# 5      Using Machine Learning in Trading and Finance      4   16 mil
# 6                 Managing Machine Learning Projects    4.4     None
# 7                      Unsupervised Machine Learning    4.8  7,1 mil
# 8   Python and Machine Learning for Asset Management    3.1   13 mil
# 9                    Launching into Machine Learning    4.6   39 mil
#
#           level                     university
# 0  Intermediate                   Google Cloud
# 1      Beginner                   Google Cloud
# 2  Intermediate        Imperial College London
# ...

# %%
ml10 = "https://www.coursera.org/search?query=machine%20learning&page=10&index=prod_all_launched_products_term_optimization"
driver.get(ml10)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml10=pd.DataFrame()
ml10['course'] =curso
ml10['rating'] =rating
ml10['students'] =students
ml10['level'] =nivel
ml10['university'] =universidad

ml10
# Out:
#                                               course rating students  \
# 0  Machine Learning Rapid Prototyping with IBM Wa...   None     None
# 1  Data Engineering and Machine Learning using Spark    3.6  3,1 mil
# 2  Create Machine Learning Models in Microsoft Azure    4.7  2,3 mil
# 3                    Machine Learning Using SAS Viya    4.7  6,7 mil
# 4  Deploy Machine Learning Model into AWS Cloud S...    4.3     None
# 5  Google Cloud Big Data and Machine Learning Fun...    4.5  4,5 mil
# 6   MLOps (Machine Learning Operations) Fundamentals      4   24 mil
# 7        Fundamentals of Machine Learning in Finance    3.8   17 mil
# 8                Production Machine Learning Systems    4.6   21 mil
# 9  Employee Attrition Prediction Using Machine Le...   None     None
#
#           level                university
# 0  Intermediate                       IBM
# 1      Beginner                       IBM
# 2  Intermediate                 Microsoft
# ...

# %%
ml11 = "https://www.coursera.org/search?query=machine%20learning&page=11&index=prod_all_launched_products_term_optimization"
driver.get(ml11)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml11=pd.DataFrame()
ml11['course'] =curso
ml11['rating'] =rating
ml11['students'] =students
ml11['level'] =nivel
ml11['university'] =universidad

ml11
# Out:
#                                               course rating students  \
# 0                         Practical Machine Learning    4.5  140 mil
# 1  Building Machine Learning Pipelines in PySpark...    4.3  2,5 mil
# 2  End-to-End Machine Learning with TensorFlow on...    4.5   54 mil
# 3  Microsoft Azure Machine Learning for Data Scie...    4.6     None
# 4  Build a Machine Learning Web App with Streamli...    4.7  9,9 mil
# 5                       Machine Learning: Regression    4.8  150 mil
# 6  Predictive Modeling and Machine Learning with ...    4.8   11 mil
# 7                   Microsoft Azure Machine Learning    4.7  3,3 mil
# 8  Algoritmos de negociación basados en machine l...   None     None
# 9             Machine Learning Aplicado ao Marketing   None     None
#
#           level                           university
# 0         Mixed             Johns Hopkins University
# 1  Intermediate             Coursera Project Network
# ...

# %%
ml12 = "https://www.coursera.org/search?query=machine%20learning&page=12&index=prod_all_launched_products_term_optimization"
driver.get(ml12)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml12=pd.DataFrame()
ml12['course'] =curso
ml12['rating'] =rating
ml12['students'] =students
ml12['level'] =nivel
ml12['university'] =universidad

ml12
# Out:
#                                               course rating students  \
# 0       Cloud Machine Learning Engineering and MLOps    4.5  1,7 mil
# 1  Statistics for Machine Learning for Investment...   None     None
# 2  Python and Machine-Learning for Asset Manageme...    4.4   11 mil
# 3                 Machine Learning Models in Science      4     None
# 4                Art and Science of Machine Learning    4.6   23 mil
# 5  Build and Operate Machine Learning Solutions w...   None     None
# 6  Predictive Modelling with Azure Machine Learni...    4.5  9,5 mil
# 7  Fundamentals of Machine Learning for Supply Chain    3.9     None
# 8  Google Cloud Big Data and Machine Learning Fun...    4.3    2 mil
# 9  機器學習基石下 (Machine Learning Foundations)---Algor...    4.9   14 mil
#
#           level                  university
# 0  Intermediate             Duke University
# 1      Beginner               CFA Institute
# 2  Intermediate       EDHEC Business School
# ...

# %%
ml13 = "https://www.coursera.org/search?query=machine%20learning&page=13&index=prod_all_launched_products_term_optimization"
driver.get(ml13)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml13=pd.DataFrame()
ml13['course'] =curso
ml13['rating'] =rating
ml13['students'] =students
ml13['level'] =nivel
ml13['university'] =universidad

ml13
# Out:
#                                               course rating students  \
# 0    Applying Machine Learning to your Data with GCP    4.7   16 mil
# 1                     Machine Learning With Big Data    4.6   63 mil
# 2  Life Expectancy Prediction Using Machine Learning   None     None
# 3  Interpretable Machine Learning Applications: P...      4     None
# 4  Using R for Regression and Machine Learning in...   None     None
# 5  Interactive Machine Learning Dashboards using ...    4.4     None
# 6  Google Cloud Big Data and Machine Learning Fun...    4.7   18 mil
# 7  Explainable Machine Learning with LIME and H2O...    4.7    2 mil
# 8  Managing Machine Learning Projects with Google...    4.6  110 mil
# 9  Smart Analytics, Machine Learning, and AI on G...    4.6     None
#
#           level                          university
# 0  Intermediate                        Google Cloud
# 1         Mixed  University of California San Diego
# ...

# %%
ml14 = "https://www.coursera.org/search?query=machine%20learning&page=14&index=prod_all_launched_products_term_optimization"
driver.get(ml14)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml14=pd.DataFrame()
ml14['course'] =curso
ml14['rating'] =rating
ml14['students'] =students
ml14['level'] =nivel
ml14['university'] =universidad

ml14
# Out:
#                                               course rating students  \
# 0                  Practical Machine Learning on H2O    4.5  7,5 mil
# 1               Ensemble Methods in Machine Learning    4.2     None
# 2  Intermediate Machine Learning: TensorFlow on G...    4.4     None
# 3                   Machine Learning: Classification    4.7  110 mil
# 4   Machine Learning - Anomaly Detection via PyCaret   None     None
# 5        Machine Learning for Accounting with Python    4.5  6,6 mil
# 6                      Train Machine Learning Models   None     None
# 7  Machine Learning for Kyphosis Disease Classifi...   None     None
# 8      Machine Learning for Investment Professionals   None     None
# 9  Launching Machine Learning: Delivering Operati...    4.9  3,4 mil
#
#           level                                  university
# 0  Intermediate                                         H2O
# 1  Intermediate                    Coursera Project Network
# ...

# %%
ml15 = "https://www.coursera.org/search?query=machine%20learning&page=15&index=prod_all_launched_products_term_optimization"
driver.get(ml15)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml15=pd.DataFrame()
ml15['course'] =curso
ml15['rating'] =rating
ml15['students'] =students
ml15['level'] =nivel
ml15['university'] =universidad

ml15
# Out:
#                                               course rating students  \
# 0        How Google does Machine Learning en Español    4.6  6,2 mil
# 1  AI Workflow: Machine Learning, Visual Recognit...    4.4  3,1 mil
# 2     Data Science on Google Cloud: Machine Learning    2.3     None
# 3           Machine Learning: Clustering & Retrieval    4.7   88 mil
# 4  Build your first Machine Learning Pipeline usi...    4.6     None
# 5  Business Application of Machine Learning and A...    4.2  5,7 mil
# 6                 Machine Learning for Data Analysis    4.2   42 mil
# 7  Solve Business Problems with AI and Machine Le...    4.7    2 mil
# 8  Cervical Cancer Risk Prediction Using Machine ...    4.7     None
# 9                 Explaining machine learning models   None     None
#
#           level                university
# 0  Intermediate              Google Cloud
# 1      Advanced                       IBM
# 2      Advanced              Google Cloud
# ...

# %%
ml16 = "https://www.coursera.org/search?query=machine%20learning&page=16&index=prod_all_launched_products_term_optimization"
driver.get(ml16)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml16=pd.DataFrame()
ml16['course'] =curso
ml16['rating'] =rating
ml16['students'] =students
ml16['level'] =nivel
ml16['university'] =universidad

ml16
# Out:
#                                               course rating students  \
# 0  Automated Machine Learning en Power BI Clasifi...    4.9     None
# 1           Visual Machine Learning with Yellowbrick    4.7  3,6 mil
# 2  Diseñando modelos con Azure Machine Learning S...    4.9     None
# 3  Google Cloud Platform Big Data and Machine Lea...    4.8    2 mil
# 4  Naive Bayes 101: Resume Selection with Machine...    4.7     None
# 5  Interpretable Machine Learning Applications: P...   None     None
# 6   Machine Learning con Spark (MLlib) en Databricks   None     None
# 7  Introduction to Machine Learning in Sports Ana...   None     None
# 8         Launching into Machine Learning en Español    4.7    3 mil
# 9       How Google does Machine Learning en Français    4.3     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2      Beginner  Coursera Project Network
# ...

# %%
ml17 = "https://www.coursera.org/search?query=machine%20learning&page=17&index=prod_all_launched_products_term_optimization"
driver.get(ml17)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml17=pd.DataFrame()
ml17['course'] =curso
ml17['rating'] =rating
ml17['students'] =students
ml17['level'] =nivel
ml17['university'] =universidad

ml17
# Out:
#                                               course rating students  \
# 0        Launching into Machine Learning en Français    4.5     None
# 1    Art and Science of Machine Learning en Français   None     None
# 2    Machine Learning Pipelines with Azure ML Studio    4.6   26 mil
# 3           Introduction to Applied Machine Learning    4.7   20 mil
# 4  Machine Learning Algorithms with R in Business...    4.7  1,5 mil
# 5               機器學習技法 (Machine Learning Techniques)    4.9  3,8 mil
# 6  Machine Learning Algorithms: Supervised Learni...    4.7   14 mil
# 7                          Data for Machine Learning    4.4  6,5 mil
# 8              Project Planning and Machine Learning    4.7    6 mil
# 9                  Deploying Machine Learning Models    3.6  8,8 mil
#
#           level                                  university
# 0  Intermediate                                Google Cloud
# 1  Intermediate                                Google Cloud
# ...

# %%
ml18 = "https://www.coursera.org/search?query=machine%20learning&page=18&index=prod_all_launched_products_term_optimization"
driver.get(ml18)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml18=pd.DataFrame()
ml18['course'] =curso
ml18['rating'] =rating
ml18['students'] =students
ml18['level'] =nivel
ml18['university'] =universidad

ml18
# Out:
#                                               course rating students  \
# 0                 Follow a Machine Learning Workflow   None     None
# 1            Optimizing Machine Learning Performance    4.6  5,5 mil
# 2  Machine Learning Under the Hood: The Technical...    4.8  3,5 mil
# 3  Titanic Survival Prediction Using Machine Lear...   None     None
# 4              How Google does Machine Learning 日本語版    4.5  2,5 mil
# 5                            Machine Learning Basics   None     None
# 6                Machine Learning e Data Mining in R   None     None
# 7  Smart Analytics, Machine Learning, and AI on G...    4.7     None
# 8  Advanced Machine Learning: Machine Learning In...   None     None
# 9  Automatic Machine Learning with H2O AutoML and...    4.8  6,3 mil
#
#           level                              university
# 0  Intermediate                               CertNexus
# 1         Mixed  Alberta Machine Intelligence Institute
# ...

# %%
ml19 = "https://www.coursera.org/search?query=machine%20learning&page=19&index=prod_all_launched_products_term_optimization"
driver.get(ml19)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml19=pd.DataFrame()
ml19['course'] =curso
ml19['rating'] =rating
ml19['students'] =students
ml19['level'] =nivel
ml19['university'] =universidad

ml19
# Out:
#                                               course rating students  \
# 0                     Machine Learning with H2O Flow    4.7  3,9 mil
# 1  Curso Completo de Machine Learning en Microsof...    4.3     None
# 2  Medical Insurance Premium Prediction with Mach...   None     None
# 3  Machine Learning: Predict Numbers from Handwri...    4.4  4,7 mil
# 4  How Google does Machine Learning em Português ...    4.8  1,6 mil
# 5   Automated Machine Learning en Microsoft Power BI    4.3     None
# 6  Smart Analytics, Machine Learning, and AI on G...    4.9     None
# 7  Deploy a predictive machine learning model usi...   None     None
# 8  Build a Machine Learning Image Classifier with...   None     None
# 9                        Machine Learning Algorithms   None     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1      Advanced  Coursera Project Network
# 2      Beginner  Coursera Project Network
# ...

# %%
ml20 = "https://www.coursera.org/search?query=machine%20learning&page=20&index=prod_all_launched_products_term_optimization"
driver.get(ml20)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml20=pd.DataFrame()
ml20['course'] =curso
ml20['rating'] =rating
ml20['students'] =students
ml20['level'] =nivel
ml20['university'] =universidad

ml20
# Out:
#                                               course rating students  \
# 0               Launching into Machine Learning 日本語版    4.4     None
# 1  Serverless Machine Learning with Tensorflow on...   None     None
# 2  Applying Machine Learning to your Data with GC...   None     None
# 3      Machine Learning con Python. Nivel intermedio   None     None
# 4  Interpretable Machine Learning Applications: P...   None     None
# 5         Preparing Data for Machine Learning Models   None     None
# 6  Machine Learning Interpretable: SHAP, PDP y pe...   None     None
# 7  Machine Learning para series temporales con AR...   None     None
# 8  Machine Learning y Regresión con PySpark. Guía...   None     None
# 9  Machine Learning con Azure Machine Learning St...   None     None
#
#           level                university
# 0  Intermediate              Google Cloud
# 1  Intermediate              Google Cloud
# 2  Intermediate              Google Cloud
# ...

# %%
ml21 = "https://www.coursera.org/search?query=machine%20learning&page=21&index=prod_all_launched_products_term_optimization"
driver.get(ml21)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml21=pd.DataFrame()
ml21['course'] =curso
ml21['rating'] =rating
ml21['students'] =students
ml21['level'] =nivel
ml21['university'] =universidad

ml21
# Out:
#                                               course rating students  \
# 0  Evaluate Machine Learning Models with Yellowbrick    4.8  2,9 mil
# 1        Generando modelos con Auto Machine Learning    4.4     None
# 2  Serverless Machine Learning with Tensorflow on...    4.4     None
# 3  Art and Science of Machine Learning em Portugu...    4.6     None
# 4  Interpretable machine learning applications: P...   None     None
# 5        Machine Learning con Python. Nivel Avanzado   None     None
# 6         Machine Learning Introduction for Everyone   None     None
# 7  Interpretable machine learning applications: P...   None     None
# 8  Machine Learning Interpretable: interpretML y ...   None     None
# 9             Interpreting Machine Learning datasets   None     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate  Coursera Project Network
# 2  Intermediate              Google Cloud
# ...

# %%
ml22 = "https://www.coursera.org/search?query=machine%20learning&page=22&index=prod_all_launched_products_term_optimization"
driver.get(ml22)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml22=pd.DataFrame()
ml22['course'] =curso
ml22['rating'] =rating
ml22['students'] =students
ml22['level'] =nivel
ml22['university'] =universidad

ml22
# Out:
#                                               course rating students  \
# 0  Machine Learning: Predict Poisonous Mushrooms ...    4.6  4,5 mil
# 1     Art and Science of Machine Learning en Español    4.6  2,2 mil
# 2  Launching into Machine Learning em Português B...    4.5     None
# 3  Smart Analytics, Machine Learning, and AI on G...   None     None
# 4           Art and Science of Machine Learning 日本語版    4.3     None
# 5  Crea un app de Machine Learning con Spark, Syn...   None     None
# 6  Machine Learning con Pyspark aplicado al campo...   None     None
# 7  Introdução a Machine Learning em uma Competiçã...   None     None
# 8  Desplegando modelos de Machine Learning con Py...   None     None
# 9  Aplicando privacidad en modelos de Machine Lea...   None     None
#
#           level                university
# 0  Intermediate  Coursera Project Network
# 1  Intermediate              Google Cloud
# 2  Intermediate              Google Cloud
# ...

# %%
ml23= "https://www.coursera.org/search?query=machine%20learning&page=23&index=prod_all_launched_products_term_optimization"
driver.get(ml23)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml23=pd.DataFrame()
ml23['course'] =curso
ml23['rating'] =rating
ml23['students'] =students
ml23['level'] =nivel
ml23['university'] =universidad

ml23
# Out:
#                                               course rating students  \
# 0        Unsupervised Algorithms in Machine Learning   None     None
# 1  Bike Rental Sharing Demand Prediction with Mac...   None     None
# 2     Machine Learning: Algorithms in the Real World    4.6   30 mil
# 3  Machine Learning with TensorFlow Google Cloud ...    4.4  2,8 mil
# 4  Machine Learning with TensorFlow on Google Clo...    4.7    2 mil
# 5  Machine Learning for Analytics MasterTrack™ Ce...   None     None
# 6    AI and Machine Learning MasterTrack Certificate   None     None
# 7  Master of Science in Machine Learning and Data...   None     None
# 8  Post Graduate Certificate in Data Science & Ma...   None     None
# 9                               IBM Data Engineering    4.6  500 mil
#
#           level                              university
# 0  Intermediate          University of Colorado Boulder
# 1      Beginner                Coursera Project Network
# ...

# %%
ml24= "https://www.coursera.org/search?query=machine%20learning&page=24&index=prod_all_launched_products_term_optimization"
driver.get(ml24)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml24=pd.DataFrame()
ml24['course'] =curso
ml24['rating'] =rating
ml24['students'] =students
ml24['level'] =nivel
ml24['university'] =universidad

ml24
# Out:
#                                               course rating students  \
# 0                                    AI For Everyone    4.8  750 mil
# 1                    TensorFlow: Advanced Techniques    4.8   27 mil
# 2                             Practical Data Science    4.5   16 mil
# 3  Introduction to Discrete Mathematics for Compu...    4.5  160 mil
# 4          Python for Data Science, AI & Development    4.6  380 mil
# 5                                           Big Data    4.5  340 mil
# 6         Computational Thinking for Problem Solving    4.7   75 mil
# 7        Convolutional Neural Networks in TensorFlow    4.7  110 mil
# 8               Advanced Statistics for Data Science    4.4   94 mil
# 9                          Data Analysis with Python    4.7  230 mil
#
#           level                          university
# 0      Beginner                     DeepLearning.AI
# 1  Intermediate                     DeepLearning.AI
# ...

# %%
ml25= "https://www.coursera.org/search?query=machine%20learning&page=25&index=prod_all_launched_products_term_optimization"
driver.get(ml25)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml25=pd.DataFrame()
ml25['course'] =curso
ml25['rating'] =rating
ml25['students'] =students
ml25['level'] =nivel
ml25['university'] =universidad

ml25
# Out:
#                                               course rating students  \
# 0             Introduction to Data Science in Python    4.5  660 mil
# 1              Sequences, Time Series and Prediction    4.7   91 mil
# 2                           AI for Medical Diagnosis    4.7   50 mil
# 3           An Intuitive Introduction to Probability    4.8   49 mil
# 4          Applied Social Network Analysis in Python    4.7   85 mil
# 5  Building Recommendation System Using MXNET on ...      3     None
# 6                          Exploratory Data Analysis    4.2  5,2 mil
# 7  Introduction to Data Science and scikit-learn ...    3.8     None
# 8                  Aprendizado de máquina com Python   None     None
# 9                       ML Pipelines on Google Cloud    3.5  5,4 mil
#
#           level                university
# 0  Intermediate    University of Michigan
# 1  Intermediate           DeepLearning.AI
# 2  Intermediate           DeepLearning.AI
# ...

# %%
ml26= "https://www.coursera.org/search?query=machine%20learning&page=26&index=prod_all_launched_products_term_optimization"
driver.get(ml26)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml26=pd.DataFrame()
ml26['course'] =curso
ml26['rating'] =rating
ml26['students'] =students
ml26['level'] =nivel
ml26['university'] =universidad

ml26
# Out:
#                                           course rating students  \
# 0         Object Detection with Amazon Sagemaker    4.5    7 mil
# 1     Math for AI beginner part 1 Linear Algebra   None     None
# 2    Semantic Segmentation with Amazon Sagemaker    4.6  5,5 mil
# 3                 الشبكات العصبية والتعلم العميق    4.6  3,9 mil
# 4              التعلّم الآلي باستخدام لغة بايثون   None     None
# 5     Build a Classification Model using PyCaret   None     None
# 6                   Introduction to Data Science    4.6  690 mil
# 7  Data Science Fundamentals with Python and SQL    4.6  570 mil
# 8                  Key Technologies for Business    4.7  730 mil
# 9                           Applied Data Science    4.6  500 mil
#
#           level                                         university
# 0      Advanced                           Coursera Project Network
# 1      Beginner  Korea Advanced Institute of Science and Techno...
# ...

# %%
ml27= "https://www.coursera.org/search?query=machine%20learning&page=27&index=prod_all_launched_products_term_optimization"
driver.get(ml27)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml27=pd.DataFrame()
ml27['course'] =curso
ml27['rating'] =rating
ml27['students'] =students
ml27['level'] =nivel
ml27['university'] =universidad

ml27
# Out:
#                                               course rating students  \
# 0                    IBM AI Foundations for Business    4.7  680 mil
# 1                      IBM & Darden Digital Strategy    4.7  360 mil
# 2                                     IBM Applied AI    4.6  530 mil
# 3                  Learn SQL Basics for Data Science    4.6  400 mil
# 4                        Natural Language Processing    4.6  110 mil
# 5  Preparing for Google Cloud Certification: Clou...    4.7  610 mil
# 6  Preparing for Google Cloud Certification: Clou...    4.7  610 mil
# 7  Preparing for Google Cloud Certification: Clou...    4.6  250 mil
# 8                                         Blockchain    4.6  190 mil
# 9         Architecting with Google Kubernetes Engine    4.7  580 mil
#
#           level                       university
# 0      Beginner                              IBM
# 1      Beginner                              IBM
# 2      Beginner                              IBM
# ...

# %%
ml28= "https://www.coursera.org/search?query=machine%20learning&page=28&index=prod_all_launched_products_term_optimization"
driver.get(ml28)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml28=pd.DataFrame()
ml28['course'] =curso
ml28['rating'] =rating
ml28['students'] =students
ml28['level'] =nivel
ml28['university'] =universidad

ml28
# Out:
#                                               course rating students  \
# 0  Preparing for Google Cloud Certification: Clou...    4.7  590 mil
# 1                                   AI in Healthcare    4.7   28 mil
# 2  Preparing for Google Cloud Certification: Clou...    4.7  650 mil
# 3  Preparing for Google Cloud Certification: Clou...    4.7  580 mil
# 4                         Networking in Google Cloud    4.7  580 mil
# 5          Developing Applications with Google Cloud    4.7  590 mil
# 6                                         Algorithms    4.8  220 mil
# 7                           Security in Google Cloud    4.7  580 mil
# 8    Modern Application Development with Java on AWS    4.8   83 mil
# 9                  Neural Networks and Deep Learning    4.9      1 m
#
#           level           university
# 0  Intermediate         Google Cloud
# 1      Beginner  Stanford University
# 2      Beginner         Google Cloud
# 3  Intermediate         Google Cloud
# ...

# %%
ml29= "https://www.coursera.org/search?query=machine%20learning&page=29&index=prod_all_launched_products_term_optimization"
driver.get(ml29)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml29=pd.DataFrame()
ml29['course'] =curso
ml29['rating'] =rating
ml29['students'] =students
ml29['level'] =nivel
ml29['university'] =universidad

ml29
# Out:
#                                               course rating students  \
# 0          Accelerated Computer Science Fundamentals    4.7   73 mil
# 1                        AI Foundations for Everyone    4.7  180 mil
# 2                                  Self-Driving Cars    4.7  130 mil
# 3               Geographic Information Systems (GIS)    4.8  140 mil
# 4             NoSQL, Big Data, and Spark Foundations    4.3   11 mil
# 5                             Tools for Data Science    4.5  260 mil
# 6                                  Statistics with R    4.6  330 mil
# 7      Microsoft Azure Fundamentals AZ-900 Exam Prep    4.6   36 mil
# 8  Microsoft Azure Data Engineering Associate DP-...    4.4  7,5 mil
# 9    MATLAB Programming for Engineers and Scientists    4.8  440 mil
#
#           level                                  university
# 0  Intermediate  University of Illinois at Urbana-Champaign
# 1      Beginner                                         IBM
# ...

# %%
ml30= "https://www.coursera.org/search?query=machine%20learning&page=30&index=prod_all_launched_products_term_optimization"
driver.get(ml30)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml30=pd.DataFrame()
ml30['course'] =curso
ml30['rating'] =rating
ml30['students'] =students
ml30['level'] =nivel
ml30['university'] =universidad

ml30
# Out:
#                                               course rating students  \
# 0  Improving Deep Neural Networks: Hyperparameter...    4.9  440 mil
# 1       Impact Measurement & Management for the SDGs    4.8  7,4 mil
# 2                   Analyze Data to Answer Questions    4.6  120 mil
# 3                                    AI for Medicine    4.7   53 mil
# 4         Financial Technology (Fintech) Innovations    4.7   53 mil
# 5          Algorithms for Battery Management Systems    4.7   39 mil
# 6                     Biostatistics in Public Health    4.8   43 mil
# 7               AI For Everyone （すべての人のためのAIリテラシー講座）    4.8   18 mil
# 8                     Advanced Data Science with IBM    4.3  110 mil
# 9                         Программирование на Python    4.5   80 mil
#
#           level                                  university
# 0  Intermediate                             DeepLearning.AI
# 1         Mixed                             Duke University
# ...

# %%
ml31= "https://www.coursera.org/search?query=machine%20learning&page=31&index=prod_all_launched_products_term_optimization"
driver.get(ml31)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml31=pd.DataFrame()
ml31['course'] =curso
ml31['rating'] =rating
ml31['students'] =students
ml31['level'] =nivel
ml31['university'] =universidad

ml31
# Out:
#                                               course rating students  \
# 0                      Neuroscience and Neuroimaging    4.6   93 mil
# 1       Creating Business Value with Data and Looker    4.8   17 mil
# 2  Natural Language Processing with Classificatio...    4.6  100 mil
# 3                     Probabilistic Graphical Models    4.6   84 mil
# 4                             Statistics with Python    4.6  110 mil
# 5                      Convolutional Neural Networks    4.9  400 mil
# 6      Statistical Analysis with R for Public Health    4.7   42 mil
# 7                                           Robotics    4.4  150 mil
# 8                                 Interaction Design    4.5  200 mil
# 9                 GIS, Mapping, and Spatial Analysis    4.9   64 mil
#
#           level                          university
# 0  Intermediate            Johns Hopkins University
# 1  Intermediate                        Google Cloud
# ...

# %%
ml32= "https://www.coursera.org/search?query=machine%20learning&page=32&index=prod_all_launched_products_term_optimization"
driver.get(ml32)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml32=pd.DataFrame()
ml32['course'] =curso
ml32['rating'] =rating
ml32['students'] =students
ml32['level'] =nivel
ml32['university'] =universidad

ml32
# Out:
#                                               course rating students  \
# 0                           PostgreSQL for Everybody    4.8   15 mil
# 1                        Advanced Business Analytics    4.6  210 mil
# 2                   Learn English: Beginning Grammar    4.9   12 mil
# 3                                 Health Informatics    4.4   31 mil
# 4  Build Basic Generative Adversarial Networks (G...    4.7   38 mil
# 5  Customer Experiences with Contact Center AI - ...    4.4  3,7 mil
# 6            From Data to Insights with Google Cloud    4.6   59 mil
# 7  Microsoft Azure Data Scientist Associate - DP-...    4.6  3,2 mil
# 8     Google Cloud Fundamentals: Core Infrastructure    4.7  580 mil
# 9          Digital Manufacturing & Design Technology    4.6   89 mil
#
#           level                        university
# 0  Intermediate            University of Michigan
# 1  Intermediate    University of Colorado Boulder
# 2      Beginner  University of California, Irvine
# ...

# %%
ml33= "https://www.coursera.org/search?query=machine%20learning&page=33&index=prod_all_launched_products_term_optimization"
driver.get(ml33)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml33=pd.DataFrame()
ml33['course'] =curso
ml33['rating'] =rating
ml33['students'] =students
ml33['level'] =nivel
ml33['university'] =universidad

ml33
# Out:
#                                               course rating students  \
# 0                                        Data Mining    4.5  190 mil
# 1  Microsoft Azure Data Fundamentals DP-900 Exam ...    4.7  7,1 mil
# 2                            Ciencia de Datos de IBM    4.5  7,4 mil
# 3                                    AI For Business    4.6  2,4 mil
# 4                           Analista de Datos de IBM    4.4   11 mil
# 5  Digital Transformation Using AI/ML with Google...    4.6  150 mil
# 6  Customer Experiences with Contact Center AI - ...    4.4  3,7 mil
# 7                  Systems Biology and Biotechnology    4.4   66 mil
# 8                                   Agile Leadership    4.7   13 mil
# 9                                Recommender Systems    4.3   42 mil
#
#           level                                  university
# 0  Intermediate  University of Illinois at Urbana-Champaign
# 1      Beginner                                   Microsoft
# ...

# %%
ml34= "https://www.coursera.org/search?query=machine%20learning&page=34&index=prod_all_launched_products_term_optimization"
driver.get(ml34)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml34=pd.DataFrame()
ml34['course'] =curso
ml34['rating'] =rating
ml34['students'] =students
ml34['level'] =nivel
ml34['university'] =universidad

ml34
# Out:
#                                               course rating students  \
# 0          Natural Language Processing in TensorFlow    4.6  100 mil
# 1                    TensorFlow: Data and Deployment    4.6   40 mil
# 2             Fundamentals of Reinforcement Learning    4.8   61 mil
# 3  Preparing for Google Cloud Certification: Clou...    4.5  4,9 mil
# 4                     Extended Reality for Everybody    4.6  9,8 mil
# 5        Building Cloud Computing Solutions at Scale    4.5  9,2 mil
# 6                     TensorFlow 2 for Deep Learning    4.9   30 mil
# 7  Data Engineering, Big Data and ML on Google Cl...    4.5  4,7 mil
# 8  A Crash Course in Causality: Inferring Causal ...    4.7   30 mil
# 9    Open Source Software Development, Linux and Git    4.5   58 mil
#
#           level                  university
# 0  Intermediate             DeepLearning.AI
# 1  Intermediate             DeepLearning.AI
# 2  Intermediate       University of Alberta
# ...

# %%
ml35= "https://www.coursera.org/search?query=machine%20learning&page=35&index=prod_all_launched_products_term_optimization"
driver.get(ml35)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml35=pd.DataFrame()
ml35['course'] =curso
ml35['rating'] =rating
ml35['students'] =students
ml35['level'] =nivel
ml35['university'] =universidad

ml35
# Out:
#                                               course rating students  \
# 0             Process Mining: Data science in Action    4.7   63 mil
# 1                                 Business Analytics    4.6   57 mil
# 2  Analyze Datasets and Train ML Models using AutoML    4.5   14 mil
# 3          Responsive Website Development and Design    4.5  250 mil
# 4                                            程序设计与算法    4.8   93 mil
# 5                  Swift 5 iOS Application Developer    4.5   23 mil
# 6              Unity XR: How to Build AR and VR Apps    4.1   30 mil
# 7  Natural Language Processing with Probabilistic...    4.7   43 mil
# 8                       Embedding Sensors and Motors    4.6   61 mil
# 9     Data Science with Databricks for Data Analysts    4.5   14 mil
#
#           level                                  university
# 0  Intermediate          Eindhoven University of Technology
# 1      Beginner  University of Illinois at Urbana-Champaign
# ...

# %%
ml36= "https://www.coursera.org/search?query=machine%20learning&page=36&index=prod_all_launched_products_term_optimization"
driver.get(ml36)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml36=pd.DataFrame()
ml36['course'] =curso
ml36['rating'] =rating
ml36['students'] =students
ml36['level'] =nivel
ml36['university'] =universidad

ml36
# Out:
#                                              course rating students  \
# 0                                          AI & Law    4.7  9,4 mil
# 1                     Analytics for Decision Making    4.7  4,8 mil
# 2      Introduction to Artificial Intelligence (AI)    4.7  160 mil
# 3    Машинное обучение: от статистики до нейросетей    4.4  6,1 mil
# 4              Artificial Intelligence in Marketing    4.6  8,7 mil
# 5  Microsoft Azure AI Fundamentals AI-900 Exam Prep    4.7  7,4 mil
# 6                        IBM AI Enterprise Workflow    4.3  9,7 mil
# 7                             Clinical Data Science    4.5   19 mil
# 8                           Uncommon Sense Teaching    4.8   12 mil
# 9                        Strategic Sales Management    4.5   21 mil
#
#           level                           university
# 0         Mixed                      Lund University
# 1      Beginner              University of Minnesota
# 2      Beginner                                  IBM
# ...

# %%
ml37= "https://www.coursera.org/search?query=machine%20learning&page=37&index=prod_all_launched_products_term_optimization"
driver.get(ml37)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml37=pd.DataFrame()
ml37['course'] =curso
ml37['rating'] =rating
ml37['students'] =students
ml37['level'] =nivel
ml37['university'] =universidad

ml37
# Out:
#                                               course rating students  \
# 0  Mind Control: Managing Your Mental Health Duri...    4.8  180 mil
# 1                  Introduction to Self-Driving Cars    4.7  120 mil
# 2  Introduction to Portfolio Construction and Ana...    4.8   44 mil
# 3            Digitalisation in Aeronautics and Space    4.6    8 mil
# 4  Microsoft Azure Developer Associate AZ-204 Tes...    4.5  2,4 mil
# 5  Build Better Generative Adversarial Networks (...    4.7   16 mil
# 6                       Computational Social Science    4.6   35 mil
# 7  Foundations of Teaching for Learning: Being a ...    4.6   44 mil
# 8     Introduction to Microsoft Azure Cloud Services    4.6   32 mil
# 9  Biology Meets Programming: Bioinformatics for ...    4.2  130 mil
#
#           level                            university
# 0      Beginner                 University of Toronto
# 1      Advanced                 University of Toronto
# ...

# %%
ml38= "https://www.coursera.org/search?query=machine%20learning&page=38&index=prod_all_launched_products_term_optimization"
driver.get(ml38)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml38=pd.DataFrame()
ml38['course'] =curso
ml38['rating'] =rating
ml38['students'] =students
ml38['level'] =nivel
ml38['university'] =universidad

ml38
# Out:
#                                               course rating students  \
# 0  Custom Models, Layers, and Loss Functions with...    4.9   17 mil
# 1                 Cloud Computing Basics (Cloud 101)    4.5  130 mil
# 2                                    Cloud Computing    4.4  170 mil
# 3   Natural Language Processing with Sequence Models    4.5   37 mil
# 4  Natural Language Processing with Attention Models    4.3   37 mil
# 5       Introduction to Augmented Reality and ARCore    4.5   67 mil
# 6       Image Processing for Engineering and Science    4.6     None
# 7         Sleep: Neurobiology, Medicine, and Society    4.8   46 mil
# 8  Architecting Hybrid Cloud Infrastructure with ...    4.7  9,2 mil
# 9                            Ordered Data Structures    4.8   17 mil
#
#           level                                  university
# 0  Intermediate                             DeepLearning.AI
# 1      Beginner                                  LearnQuest
# ...

# %%
ml39= "https://www.coursera.org/search?query=machine%20learning&page=39&index=prod_all_launched_products_term_optimization"
driver.get(ml39)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml39=pd.DataFrame()
ml39['course'] =curso
ml39['rating'] =rating
ml39['students'] =students
ml39['level'] =nivel
ml39['university'] =universidad

ml39
# Out:
#                                               course rating students  \
# 0  Foundations of Data Science: K-Means Clusterin...    4.7   27 mil
# 1         Interviewing and Resume Writing in English    4.6  110 mil
# 2                Summary Statistics in Public Health    4.8   34 mil
# 3                          Accounting Data Analytics    4.7   29 mil
# 4           Advanced Computer Vision with TensorFlow    4.8   16 mil
# 5  Big Data – Introducción al uso práctico de dat...    4.6   44 mil
# 6       Apply Generative Adversarial Networks (GANs)    4.8   14 mil
# 7                                         Psicología    4.8   24 mil
# 8   Build, Train, and Deploy ML Pipelines using BERT    4.6  6,4 mil
# 9                Word Forms and Simple Present Tense    4.9   12 mil
#
#           level                                  university
# 0      Beginner                        University of London
# 1  Intermediate        University of Maryland, College Park
# ...

# %%
ml40= "https://www.coursera.org/search?query=machine%20learning&page=40&index=prod_all_launched_products_term_optimization"
driver.get(ml40)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml40=pd.DataFrame()
ml40['course'] =curso
ml40['rating'] =rating
ml40['students'] =students
ml40['level'] =nivel
ml40['university'] =universidad

ml40
# Out:
#                                               course rating students  \
# 0                                     Model Thinking    4.8  180 mil
# 1                   Data Analysis and Interpretation    4.4  140 mil
# 2               Introduction to Applied Cryptography    4.6   29 mil
# 3                             Healthcare Marketplace    4.5   61 mil
# 4                               Applied Cryptography    4.5   23 mil
# 5                         Computational Neuroscience    4.6   95 mil
# 6         Bayesian Statistics: Techniques and Models    4.8   48 mil
# 7       Healthcare Trends for Business Professionals    4.4   12 mil
# 8  Preparing for Google Cloud Certification: Clou...    4.8   18 mil
# 9                      Introduction to Clinical Data    4.6  8,4 mil
#
#           level                            university
# 0         Mixed                University of Michigan
# 1      Beginner                   Wesleyan University
# ...

# %%
ml41= "https://www.coursera.org/search?query=machine%20learning&page=41&index=prod_all_launched_products_term_optimization"
driver.get(ml41)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml41=pd.DataFrame()
ml41['course'] =curso
ml41['rating'] =rating
ml41['students'] =students
ml41['level'] =nivel
ml41['university'] =universidad

ml41
# Out:
#                                             course rating students  \
# 0  Custom and Distributed Training with TensorFlow    4.8  9,1 mil
# 1                    Sample-based Learning Methods    4.8   22 mil
# 2                    Applied Data Science Capstone    4.7   93 mil
# 3            Innovating with Data and Google Cloud    4.8  8,5 mil
# 4                            Data-driven Astronomy    4.8   26 mil
# 5                   Practical Time Series Analysis    4.6   66 mil
# 6                        Ciencia de Datos Aplicada    4.6  3,5 mil
# 7         Developing Industrial Internet of Things    4.6   25 mil
# 8                    SAS Visual Business Analytics    4.7   26 mil
# 9      Embedded Software and Hardware Architecture    4.5   29 mil
#
#           level                        university
# 0  Intermediate                   DeepLearning.AI
# 1  Intermediate             University of Alberta
# 2  Intermediate                               IBM
# ...

# %%
ml42= "https://www.coursera.org/search?query=machine%20learning&page=42&index=prod_all_launched_products_term_optimization"
driver.get(ml42)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml42=pd.DataFrame()
ml42['course'] =curso
ml42['rating'] =rating
ml42['students'] =students
ml42['level'] =nivel
ml42['university'] =universidad

ml42
# Out:
#                                               course rating students  \
# 0                 Data-Driven Decision Making (DDDM)    4.5  7,7 mil
# 1                                Statistics with SAS    4.8   24 mil
# 2  Fundamentals of Digital Image and Video Proces...    4.6  110 mil
# 3                                      Data Literacy    4.6  5,4 mil
# 4                           AI for Medical Prognosis    4.7   19 mil
# 5              Fundamentals of Scalable Data Science    4.3   63 mil
# 6                  Deep Neural Networks with PyTorch    4.4   32 mil
# 7               Distributed Computing with Spark SQL    4.5   27 mil
# 8  Introduction to Deep Learning & Neural Network...    4.7   23 mil
# 9  Preparing for Google Cloud Certification: Clou...    4.7   20 mil
#
#           level                       university
# 0      Beginner            University at Buffalo
# 1  Intermediate                              SAS
# 2         Mixed          Northwestern University
# ...

# %%
ml43= "https://www.coursera.org/search?query=machine%20learning&page=43&index=prod_all_launched_products_term_optimization"
driver.get(ml43)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml43=pd.DataFrame()
ml43['course'] =curso
ml43['rating'] =rating
ml43['students'] =students
ml43['level'] =nivel
ml43['university'] =universidad

ml43
# Out:
#                                               course rating students  \
# 0  Data Engineering, Big Data and ML on Google Cl...    4.7   19 mil
# 1                       The Basics of Trauma Surgery    4.5   11 mil
# 2        Bases de Inteligencia Artificial para Todos    4.7    8 mil
# 3  Introduction to Computer Vision and Image Proc...    4.4   28 mil
# 4  Protecting the World: Introducing Corrosion Sc...    4.6   12 mil
# 5             Liderazgo y habilidades de negociación    4.7  3,8 mil
# 6  Architecting with Google Compute Engine en Esp...    4.8   17 mil
# 7                           Solving Complex Problems    4.6   24 mil
# 8  Greedy Algorithms, Minimum Spanning Trees, and...    4.8   62 mil
# 9                            Supply Chain Excellence    4.7  8,8 mil
#
#           level                                  university
# 0  Intermediate                                Google Cloud
# 1  Intermediate        Technische Universität München (TUM)
# ...

# %%
ml44= "https://www.coursera.org/search?query=machine%20learning&page=44&index=prod_all_launched_products_term_optimization"
driver.get(ml44)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml44=pd.DataFrame()
ml44['course'] =curso
ml44['rating'] =rating
ml44['students'] =students
ml44['level'] =nivel
ml44['university'] =universidad

ml44
# Out:
#                                               course rating students  \
# 0  Philosophy and the Sciences: Introduction to t...    4.6   63 mil
# 1  Emerging Technologies: From Smartphones to IoT...    4.7   75 mil
# 2                              Rédaction de contrats    4.8   20 mil
# 3               Supervision du raisonnement clinique    4.8    2 mil
# 4  Apprendre comment apprendre (ACA) : Des outils...    4.8   26 mil
# 5                          Data Science Fundamentals    4.1  5,4 mil
# 6              Improving your statistical inferences    4.9   61 mil
# 7                     A Crash Course in Data Science    4.5  180 mil
# 8                    NLP: Twitter Sentiment Analysis    4.6  8,6 mil
# 9   Sentiment Analysis with Deep Learning using BERT    4.5   12 mil
#
#           level                          university
# 0         Mixed         The University of Edinburgh
# 1      Beginner                   Yonsei University
# ...

# %%
ml45= "https://www.coursera.org/search?query=machine%20learning&page=45&index=prod_all_launched_products_term_optimization"
driver.get(ml45)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml45=pd.DataFrame()
ml45['course'] =curso
ml45['rating'] =rating
ml45['students'] =students
ml45['level'] =nivel
ml45['university'] =universidad

ml45
# Out:
#                                               course rating students  \
# 0       Evaluations of AI Applications in Healthcare    4.5  5,5 mil
# 1     Introduction to XR: VR, AR, and MR Foundations    4.2   22 mil
# 2  The Social and Technical Context of Health Inf...    4.2   20 mil
# 3                            Mastering Digital Twins      4  6,6 mil
# 4           Getting Started with AI using IBM Watson    4.5   33 mil
# 5  Autodesk Certified Professional: Revit for Str...    4.7   27 mil
# 6              Infection Prevention in Nursing Homes    4.8   21 mil
# 7                           Applied Digital Literacy    4.8  1,6 mil
# 8      Probability and Statistics: To p or not to p?    4.6   66 mil
# 9  Strategising: Management for Global Competitiv...    4.8   36 mil
#
#       level                                       university
# 0  Beginner                              Stanford University
# 1  Beginner                                            Unity
# ...

# %%
ml46= "https://www.coursera.org/search?query=machine%20learning&page=46&index=prod_all_launched_products_term_optimization"
driver.get(ml46)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml46=pd.DataFrame()
ml46['course'] =curso
ml46['rating'] =rating
ml46['students'] =students
ml46['level'] =nivel
ml46['university'] =universidad

ml46
# Out:
#                                               course rating students  \
# 0              Motion Planning for Self-Driving Cars    4.8   29 mil
# 1                             Transformación digital    4.8  1,6 mil
# 2                                The Bilingual Brain    4.6   28 mil
# 3  Intro to AR/VR/MR/XR: Technologies, Applicatio...    4.7  7,1 mil
# 4  Analítica de Procesos: Optimización desde los ...    4.9     None
# 5  HR Analytics- Build an HR dashboard using Powe...    4.3     None
# 6  Data Science in Stratified Healthcare and Prec...    4.6   17 mil
# 7                  Particle Physics: an Introduction    4.4   67 mil
# 8   Building AI Powered Chatbots Without Programming    4.8   39 mil
# 9           Generative Deep Learning with TensorFlow    4.8  7,3 mil
#
#           level                   university
# 0      Advanced        University of Toronto
# 1      Beginner                          BCG
# 2         Mixed        University of Houston
# ...

# %%
ml47= "https://www.coursera.org/search?query=machine%20learning&page=47&index=prod_all_launched_products_term_optimization"
driver.get(ml47)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml47=pd.DataFrame()
ml47['course'] =curso
ml47['rating'] =rating
ml47['students'] =students
ml47['level'] =nivel
ml47['university'] =universidad

ml47
# Out:
#                                               course rating students  \
# 0                                   MRI Fundamentals    4.6   15 mil
# 1                          AI in Healthcare Capstone    4.7  3,6 mil
# 2  Detecting COVID-19 with Chest X-Ray using PyTorch    4.5  9,9 mil
# 3  Preparing for the Google Cloud Professional Da...    4.6   37 mil
# 4                  Getting started with TensorFlow 2    4.9   25 mil
# 5  Introduction to High-Performance and Parallel ...      3  5,1 mil
# 6              Interactive Teaching（インタラクティブ・ティーチング）    4.7  1,7 mil
# 7  Philosophy, Science and Religion: Science and ...    4.5   43 mil
# 8  Data Engineer, Big Data and ML on Google Cloud...    4.4  2,3 mil
# 9                                   Mind and Machine    4.4   15 mil
#
#           level                                         university
# 0  Intermediate  Korea Advanced Institute of Science and Techno...
# 1         Mixed                                Stanford University
# ...

# %%
ml48= "https://www.coursera.org/search?query=machine%20learning&page=48&index=prod_all_launched_products_term_optimization"
driver.get(ml48)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml48=pd.DataFrame()
ml48['course'] =curso
ml48['rating'] =rating
ml48['students'] =students
ml48['level'] =nivel
ml48['university'] =universidad

ml48
# Out:
#                                               course rating students  \
# 0  Optimize ML Models and Deploy Human-in-the-Loo...    4.7  3,5 mil
# 1                  AI, Business & the Future of Work    4.6     None
# 2            AI Fundamentals for Non-Data Scientists    4.8     None
# 3            Materials Data Sciences and Informatics    4.5   13 mil
# 4  Oceanography: a key to better understand our w...    4.5   19 mil
# 5  Architecting with Google Kubernetes Engine en ...    4.8   16 mil
# 6                               Blockchain Platforms    4.6   25 mil
# 7              New Technologies for Business Leaders    4.4   20 mil
# 8                   Introduction to Image Processing    4.7     None
# 9  Prediction and Control with Function Approxima...    4.8   17 mil
#
#           level                                  university
# 0      Advanced                             DeepLearning.AI
# 1      Beginner                             Lund University
# ...

# %%
ml49= "https://www.coursera.org/search?query=machine%20learning&page=49&index=prod_all_launched_products_term_optimization"
driver.get(ml49)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml49=pd.DataFrame()
ml49['course'] =curso
ml49['rating'] =rating
ml49['students'] =students
ml49['level'] =nivel
ml49['university'] =universidad

ml49
# Out:
#                                               course rating students  \
# 0          Introducción a la inteligencia artificial    4.6   22 mil
# 1                        Cloud Computing Foundations    4.6  6,2 mil
# 2       Autodesk Generative Design for Manufacturing    4.8   16 mil
# 3                    Alternative Mobility Narratives    4.8  1,8 mil
# 4  Engineering Systems in Motion: Dynamics of Par...    4.9   40 mil
# 5  Introduction to Data, Signal, and Image Analys...    4.8   18 mil
# 6                Introduction to advanced tomography    4.6    3 mil
# 7                           AI For Medical Treatment    4.7   17 mil
# 8                            Ethics in the Age of AI    4.7  7,3 mil
# 9                   Sports and Building Aerodynamics    4.8   12 mil
#
#           level                               university
# 0  Intermediate  Universidad Nacional Autónoma de México
# 1      Beginner                          Duke University
# ...

# %%
ml50= "https://www.coursera.org/search?query=machine%20learning&page=50&index=prod_all_launched_products_term_optimization"
driver.get(ml50)

curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    except:
        rating.append("None")
    try:
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    except:
        students.append("None")
    try:
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
    except:
        nivel.append("None")
    try:
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        universidad.append("None")

ml50=pd.DataFrame()
ml50['course'] =curso
ml50['rating'] =rating
ml50['students'] =students
ml50['level'] =nivel
ml50['university'] =universidad

ml50
# Out:
#                                               course rating students  \
# 0             Initiation à la programmation (en C++)    4.8   39 mil
# 1  Blended Language Learning: Design and Practice...    4.8  9,4 mil
# 2  Contact Center AI: Conversational Design Funda...    4.4  3,4 mil
# 3                Introduction to Predictive Modeling    4.9  2,6 mil
# 4  Preparing for the AZ-900 Microsoft Azure Funda...    4.8  8,7 mil
# 5           Equivalent Circuit Cell Model Simulation    4.7   12 mil
# 6            Life 101: Mental and Physical Self-Care    4.8  5,2 mil
# 7  Manejo del enfermo semicrítico y crítico por C...    4.8  8,3 mil
# 8                                      IA para todos    4.9   23 mil
# 9  Microsoft Azure Management Tools and Security ...    4.8  7,5 mil
#
#           level                                university
# 0      Beginner  École Polytechnique Fédérale de Lausanne
# 1  Intermediate            University of Colorado Boulder
# ...

# %%
mlfinal = pd.concat([ml1, ml2, ml3, ml4, ml5, ml6, ml7, ml8, ml9, ml10, ml11, ml12, ml13, ml14, ml15, ml16, ml17, ml18, ml19, ml20, ml21, ml22, ml23, ml24, ml25, ml26, ml27, ml28, ml29, ml30, ml31, ml32, ml33, ml34, ml35, ml36, ml37, ml38, ml39, ml40, ml41, ml42, ml43, ml44, ml45, ml46, ml47, ml48, ml49, ml50])

# %%
mlfinal = mlfinal.reset_index()

# %%
mlfinal.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(500):
    lista.append("Machine Learning")

# %%
mlfinal['skills'] = lista

# %%
mlfinal
# Out:
#                                                 course rating students  \
# 0                                     Machine Learning    4.9    4,7 m
# 1                                 IBM Machine Learning    4.6   37 mil
# 2                                     Machine Learning    4.6  430 mil
# 3                                        Deep Learning    4.8    1,2 m
# 4                     Mathematics for Machine Learning    4.6  300 mil
# ..                                                 ...    ...      ...
# 495           Equivalent Circuit Cell Model Simulation    4.7   12 mil
# 496            Life 101: Mental and Physical Self-Care    4.8  5,2 mil
# 497  Manejo del enfermo semicrítico y crítico por C...    4.8  8,3 mil
# 498                                      IA para todos    4.9   23 mil
# 499  Microsoft Azure Management Tools and Security ...    4.8  7,5 mil
#
#             level                        university            skills
# ...

# %%
mlfinal.to_csv("machine_learning.csv")
