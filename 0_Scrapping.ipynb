# %% [markdown]
# # Scrapping

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium.webdriver.chrome.options import Options

# %%
import pandas as pd

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver,options = opciones)

# %%
import time

import warnings   # para quitar warnings
warnings.simplefilter('ignore')

# %%
url='https://www.coursera.org/search?query=&index=prod_all_launched_products_term_optimization'

# %%
PATH=ChromeDriverManager().install()
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the any command: google-chrome --version || google-chrome-stable --version
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Driver [/home/jesus_chao/.wdm/drivers/chromedriver/linux64/99.0.4844.51/chromedriver] found in cache

# %%
driver.get(url)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
    rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
"""curso = driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[1]/div/div/a/div/div/div[1]/h2").text
rating = driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[1]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text
students = driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[1]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text
nivel = driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[1]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text"""

# %%
mysql=pd.DataFrame()

# %%
mysql['curso'] =curso
mysql['rating'] =rating
mysql['students'] =students
mysql['nivel'] =nivel
mysql['universidad'] =universidad

# %%
mysql
# Out:
#                                            curso rating students    nivel  \
# 0                          Google Data Analytics    4.8  730 mil  730 mil
# 1                     Google Project Management:    4.8  520 mil  520 mil
# 2                               Google UX Design    4.8  420 mil  420 mil
# 3                               IBM Data Science    4.6      1 m      1 m
# 4                              Google IT Support    4.8    1,2 m    1,2 m
# 5                               IBM Data Analyst    4.6  720 mil  720 mil
# 6                   Introduction to Data Science    4.6  690 mil  690 mil
# 7  Data Science Fundamentals with Python and SQL    4.6  570 mil  570 mil
# 8                                  Deep Learning    4.8    1,2 m    1,2 m
# 9                           IBM Data Engineering    4.6  500 mil  500 mil
#
#        universidad
# 0           Google
# 1           Google
# 2           Google
# 3              IBM
# 4           Google
# 5              IBM
# 6              IBM
# 7              IBM
# 8  DeepLearning.AI
# 9              IBM

# %%
url2 = "https://www.coursera.org/search?page=2&index=prod_all_launched_products_term_optimization"

# %%
driver.get(url2)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
    rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mysql2=pd.DataFrame()
mysql2['curso'] =curso
mysql2['rating'] =rating
mysql2['students'] =students
mysql2['nivel'] =nivel
mysql2['universidad'] =universidad

# %%
mysql2
# Out:
#                                          curso rating students    nivel  \
# 0                Key Technologies for Business    4.7  730 mil  730 mil
# 1          IBM Data Analytics with Excel and R    4.7  200 mil  200 mil
# 2          IBM DevOps and Software Engineering    4.6  470 mil  470 mil
# 3                 Data Engineering Foundations    4.6  490 mil  490 mil
# 4  Data Analysis and Visualization Foundations    4.7  190 mil  190 mil
# 5                         Applied Data Science    4.6  500 mil  500 mil
# 6               IBM Full Stack Cloud Developer    4.6  470 mil  470 mil
# 7              IBM AI Foundations for Business    4.7  680 mil  680 mil
# 8                IBM & Darden Digital Strategy    4.7  360 mil  360 mil
# 9                             Machine Learning    4.9    4,7 m    4,7 m
#
#                                        universidad
# 0                                              IBM
# 1                                              IBM
# 2                                              IBM
# 3                                              IBM
# 4                                              IBM
# 5                                              IBM
# 6                                              IBM
# 7                                              IBM
# 8  University of Virginia Darden School Foundation
# 9                              Stanford University

# %%
url3 = "https://www.coursera.org/search?page=3&index=prod_all_launched_products_term_optimization"

# %%
driver.get(url3)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
    rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mysql3=pd.DataFrame()
mysql3['curso'] =curso
mysql3['rating'] =rating
mysql3['students'] =students
mysql3['nivel'] =nivel
mysql3['universidad'] =universidad

# %%
mysql3
# Out:
#                                                curso rating students    nivel  \
# 0                          IBM Cybersecurity Analyst    4.6  250 mil  250 mil
# 1                   Google IT Automation with Python    4.7  600 mil  600 mil
# 2                               Python for Everybody    4.8    2,7 m    2,7 m
# 3                  IT Fundamentals for Cybersecurity    4.6  230 mil  230 mil
# 4                                     IBM Applied AI    4.6  530 mil  530 mil
# 5                        IBM Data Warehouse Engineer    4.6  270 mil  270 mil
# 6                    Facebook Social Media Marketing    4.8  220 mil  220 mil
# 7  Machine Learning Engineering for Production (M...    4.7   47 mil   47 mil
# 8                               Business Foundations    4.7  670 mil  670 mil
# 9               DevOps, Cloud, and Agile Foundations    4.8   81 mil   81 mil
#
#                   universidad
# 0                         IBM
# 1                      Google
# 2      University of Michigan
# 3                         IBM
# 4                         IBM
# 5                         IBM
# 6                        Meta
# 7             DeepLearning.AI
# 8  University of Pennsylvania
# 9                         IBM

# %%
url4 = "https://www.coursera.org/search?page=4&index=prod_all_launched_products_term_optimization"

# %%
driver.get(url4)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
    rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mysql4=pd.DataFrame()
mysql4['curso'] =curso
mysql4['rating'] =rating
mysql4['students'] =students
mysql4['nivel'] =nivel
mysql4['universidad'] =universidad

# %%
mysql4
# Out:
#                                                curso rating students    nivel  \
# 0                Foundations: Data, Data, Everywhere    4.8  710 mil  710 mil
# 1                  Foundations of Project Management    4.9  490 mil  490 mil
# 2                  Learn SQL Basics for Data Science    4.6  400 mil  400 mil
# 3          Cloud Application Development Foundations    4.7   80 mil   80 mil
# 4               DeepLearning.AI TensorFlow Developer    4.7  330 mil  330 mil
# 5       Finance & Quantitative Modeling for Analysts    4.5  350 mil  350 mil
# 6  BI Foundations with SQL, ETL and Data Warehousing    4.6  250 mil  250 mil
# 7             Introduction to Finance and Accounting    4.6  410 mil  410 mil
# 8                     Technical Support Fundamentals    4.8      1 m      1 m
# 9                                  Indigenous Canada    4.8  460 mil  460 mil
#
#                        universidad
# 0                           Google
# 1                           Google
# 2  University of California, Davis
# 3                              IBM
# 4                  DeepLearning.AI
# 5       University of Pennsylvania
# 6                              IBM
# 7       University of Pennsylvania
# 8                           Google
# 9            University of Alberta

# %%
url5 = "https://www.coursera.org/search?page=5&index=prod_all_launched_products_term_optimization"

# %%
driver.get(url5)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
    rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
    students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[2]/span/span").text)
    universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mysql5=pd.DataFrame()
mysql5['curso'] =curso
mysql5['rating'] =rating
mysql5['students'] =students
mysql5['nivel'] =nivel
mysql5['universidad'] =universidad

# %%
mysql5
# Out:
#                                                curso rating students    nivel  \
# 0  Become a CBRS Certified Professional Installer...    4.7    2 mil    2 mil
# 1                    Business and Financial Modeling    4.5  220 mil  220 mil
# 2  Decentralized Finance (DeFi): The Future of Fi...    4.9   17 mil   17 mil
# 3                        Natural Language Processing    4.6  110 mil  110 mil
# 4                                 Business Analytics    4.6  370 mil  370 mil
# 5         Foundations of User Experience (UX) Design    4.8  400 mil  400 mil
# 6                          Excel Skills for Business    4.9  760 mil  760 mil
# 7                                 Intuit Bookkeeping    4.5   33 mil   33 mil
# 8  Fintech: Foundations & Applications of Financi...    4.6   70 mil   70 mil
# 9                                 IBM AI Engineering    4.6  300 mil  300 mil
#
#                   universidad
# 0   Google - Spectrum Sharing
# 1  University of Pennsylvania
# 2             Duke University
# 3             DeepLearning.AI
# 4  University of Pennsylvania
# 5                      Google
# 6        Macquarie University
# 7                      Intuit
# 8  University of Pennsylvania
# 9                         IBM

# %%
mysql = pd.concat([mysql, mysql2, mysql3, mysql4, mysql5])

# %%
mysql = mysql.reset_index()

# %%
mysql.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(50):
    lista.append("MySQL")

# %%
mysql['skills'] = lista

# %%
mysql
# Out:
#                                                 curso rating students  \
# 0                               Google Data Analytics    4.8  730 mil
# 1                          Google Project Management:    4.8  520 mil
# 2                                    Google UX Design    4.8  420 mil
# 3                                    IBM Data Science    4.6      1 m
# 4                                   Google IT Support    4.8    1,2 m
# 5                                    IBM Data Analyst    4.6  720 mil
# 6                        Introduction to Data Science    4.6  690 mil
# 7       Data Science Fundamentals with Python and SQL    4.6  570 mil
# 8                                       Deep Learning    4.8    1,2 m
# 9                                IBM Data Engineering    4.6  500 mil
# 10                      Key Technologies for Business    4.7  730 mil
# 11                IBM Data Analytics with Excel and R    4.7  200 mil
# 12                IBM DevOps and Software Engineering    4.6  470 mil
# 13                       Data Engineering Foundations    4.6  490 mil
# 14        Data Analysis and Visualization Foundations    4.7  190 mil
# 15                               Applied Data Science    4.6  500 mil
# 16                     IBM Full Stack Cloud Developer    4.6  470 mil
# 17                    IBM AI Foundations for Business    4.7  680 mil
# 18                      IBM & Darden Digital Strategy    4.7  360 mil
# 19                                   Machine Learning    4.9    4,7 m
# 20                          IBM Cybersecurity Analyst    4.6  250 mil
# 21                   Google IT Automation with Python    4.7  600 mil
# 22                               Python for Everybody    4.8    2,7 m
# 23                  IT Fundamentals for Cybersecurity    4.6  230 mil
# 24                                     IBM Applied AI    4.6  530 mil
# 25                        IBM Data Warehouse Engineer    4.6  270 mil
# 26                    Facebook Social Media Marketing    4.8  220 mil
# 27  Machine Learning Engineering for Production (M...    4.7   47 mil
# 28                               Business Foundations    4.7  670 mil
# 29               DevOps, Cloud, and Agile Foundations    4.8   81 mil
# 30                Foundations: Data, Data, Everywhere    4.8  710 mil
# 31                  Foundations of Project Management    4.9  490 mil
# 32                  Learn SQL Basics for Data Science    4.6  400 mil
# 33          Cloud Application Development Foundations    4.7   80 mil
# 34               DeepLearning.AI TensorFlow Developer    4.7  330 mil
# 35       Finance & Quantitative Modeling for Analysts    4.5  350 mil
# 36  BI Foundations with SQL, ETL and Data Warehousing    4.6  250 mil
# 37             Introduction to Finance and Accounting    4.6  410 mil
# 38                     Technical Support Fundamentals    4.8      1 m
# 39                                  Indigenous Canada    4.8  460 mil
# 40  Become a CBRS Certified Professional Installer...    4.7    2 mil
# 41                    Business and Financial Modeling    4.5  220 mil
# 42  Decentralized Finance (DeFi): The Future of Fi...    4.9   17 mil
# 43                        Natural Language Processing    4.6  110 mil
# 44                                 Business Analytics    4.6  370 mil
# 45         Foundations of User Experience (UX) Design    4.8  400 mil
# 46                          Excel Skills for Business    4.9  760 mil
# 47                                 Intuit Bookkeeping    4.5   33 mil
# 48  Fintech: Foundations & Applications of Financi...    4.6   70 mil
# 49                                 IBM AI Engineering    4.6  300 mil
#
#       nivel                                      universidad skills
# 0   730 mil                                           Google  MySQL
# 1   520 mil                                           Google  MySQL
# 2   420 mil                                           Google  MySQL
# 3       1 m                                              IBM  MySQL
# 4     1,2 m                                           Google  MySQL
# 5   720 mil                                              IBM  MySQL
# 6   690 mil                                              IBM  MySQL
# 7   570 mil                                              IBM  MySQL
# 8     1,2 m                                  DeepLearning.AI  MySQL
# 9   500 mil                                              IBM  MySQL
# 10  730 mil                                              IBM  MySQL
# 11  200 mil                                              IBM  MySQL
# 12  470 mil                                              IBM  MySQL
# 13  490 mil                                              IBM  MySQL
# 14  190 mil                                              IBM  MySQL
# 15  500 mil                                              IBM  MySQL
# 16  470 mil                                              IBM  MySQL
# 17  680 mil                                              IBM  MySQL
# 18  360 mil  University of Virginia Darden School Foundation  MySQL
# 19    4,7 m                              Stanford University  MySQL
# 20  250 mil                                              IBM  MySQL
# 21  600 mil                                           Google  MySQL
# 22    2,7 m                           University of Michigan  MySQL
# 23  230 mil                                              IBM  MySQL
# 24  530 mil                                              IBM  MySQL
# 25  270 mil                                              IBM  MySQL
# 26  220 mil                                             Meta  MySQL
# 27   47 mil                                  DeepLearning.AI  MySQL
# 28  670 mil                       University of Pennsylvania  MySQL
# 29   81 mil                                              IBM  MySQL
# 30  710 mil                                           Google  MySQL
# 31  490 mil                                           Google  MySQL
# 32  400 mil                  University of California, Davis  MySQL
# 33   80 mil                                              IBM  MySQL
# 34  330 mil                                  DeepLearning.AI  MySQL
# 35  350 mil                       University of Pennsylvania  MySQL
# 36  250 mil                                              IBM  MySQL
# 37  410 mil                       University of Pennsylvania  MySQL
# 38      1 m                                           Google  MySQL
# 39  460 mil                            University of Alberta  MySQL
# 40    2 mil                        Google - Spectrum Sharing  MySQL
# 41  220 mil                       University of Pennsylvania  MySQL
# 42   17 mil                                  Duke University  MySQL
# 43  110 mil                                  DeepLearning.AI  MySQL
# 44  370 mil                       University of Pennsylvania  MySQL
# 45  400 mil                                           Google  MySQL
# 46  760 mil                             Macquarie University  MySQL
# 47   33 mil                                           Intuit  MySQL
# 48   70 mil                       University of Pennsylvania  MySQL
# 49  300 mil                                              IBM  MySQL

# %%
mysql.to_csv("mysql.csv")

# %%
mongo1 = "https://www.coursera.org/search?query=mongo&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo1)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo1=pd.DataFrame()
mongo1['curso'] =curso
mongo1['rating'] =rating
mongo1['students'] =students
mongo1['nivel'] =nivel
mongo1['universidad'] =universidad

# %%
mongo1
# Out:
#                                                curso rating students  \
# 0                            Introduction to MongoDB    4.2      4.2
# 1  Server-side Development with NodeJS, Express a...    4.7      4.7
# 2    Introducción a bases de datos NoSQL con MongoDB   None     None
# 3    Create a C# Application to process MongoDB Data   None     None
# 4  Create a Python Application using PyMongo and ...    4.4      4.4
# 5  Use the Apache Spark Structured Streaming API ...   None     None
# 6                      MongoDB Aggregation Framework    4.5      4.5
# 7  Web Application Development with JavaScript an...    4.6      4.6
# 8  Create Your First NoSQL Database with MongoDB ...    4.6      4.6
# 9                CRUD Operations using MongoDB NoSQL    4.4      4.4
#
#                       nivel                                        universidad
# 0              Intermediate                                       MongoDB Inc.
# 1              Intermediate  The Hong Kong University of Science and Techno...
# 2  Coursera Project Network                           Coursera Project Network
# 3  Coursera Project Network                           Coursera Project Network
# 4              Intermediate                           Coursera Project Network
# 5  Coursera Project Network                           Coursera Project Network
# 6              Intermediate                                       MongoDB Inc.
# 7                     Mixed                               University of London
# 8              Intermediate                           Coursera Project Network
# 9                  Beginner                           Coursera Project Network

# %%
mongo2 = "https://www.coursera.org/search?query=mongo&page=2&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo2)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo2=pd.DataFrame()
mongo2['curso'] =curso
mongo2['rating'] =rating
mongo2['students'] =students
mongo2['nivel'] =nivel
mongo2['universidad'] =universidad

# %%
mongo3 = "https://www.coursera.org/search?query=mongo&page=3&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo3)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo3=pd.DataFrame()
mongo3['curso'] =curso
mongo3['rating'] =rating
mongo3['students'] =students
mongo3['nivel'] =nivel
mongo3['universidad'] =universidad

# %%
mongo4 = "https://www.coursera.org/search?query=mongo&page=4&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo4)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo4=pd.DataFrame()
mongo4['curso'] =curso
mongo4['rating'] =rating
mongo4['students'] =students
mongo4['nivel'] =nivel
mongo4['universidad'] =universidad

# %%
mongo5 = "https://www.coursera.org/search?query=mongo&page=5&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo5)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo5=pd.DataFrame()
mongo5['curso'] =curso
mongo5['rating'] =rating
mongo5['students'] =students
mongo5['nivel'] =nivel
mongo5['universidad'] =universidad

# %%
mongo6 = "https://www.coursera.org/search?query=mongo&page=6&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo6)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo6=pd.DataFrame()
mongo6['curso'] =curso
mongo6['rating'] =rating
mongo6['students'] =students
mongo6['nivel'] =nivel
mongo6['universidad'] =universidad

# %%
mongo7 = "https://www.coursera.org/search?query=mongo&page=7&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo7)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo7=pd.DataFrame()
mongo7['curso'] =curso
mongo7['rating'] =rating
mongo7['students'] =students
mongo7['nivel'] =nivel
mongo7['universidad'] =universidad

# %%
mongo8 = "https://www.coursera.org/search?query=mongo&page=8&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo8)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo8=pd.DataFrame()
mongo8['curso'] =curso
mongo8['rating'] =rating
mongo8['students'] =students
mongo8['nivel'] =nivel
mongo8['universidad'] =universidad

# %%
mongo9 = "https://www.coursera.org/search?query=mongo&page=9&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo9)

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongo9=pd.DataFrame()
mongo9['curso'] =curso
mongo9['rating'] =rating
mongo9['students'] =students
mongo9['nivel'] =nivel
mongo9['universidad'] =universidad

# %%
mongo10 = "https://www.coursera.org/search?query=mongo&page=10&index=prod_all_launched_products_term_optimization"

# %%
driver.get(mongo10)

# %%
mongo10=pd.DataFrame()
mongo10['curso'] =curso
mongo10['rating'] =rating
mongo10['students'] =students
mongo10['nivel'] =nivel
mongo10['universidad'] =universidad

# %%
curso =[]
rating=[]
students=[]
nivel=[]
universidad =[]

for i in range(1,11):
    try:
        curso.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/h2").text)
        rating.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        students.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[1]/div[1]/div/span[1]").text)
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[3]/div/div[2]/div/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
    except:
        rating.append("None")
        students.append("None")
        nivel.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)
        universidad.append(driver.find_element_by_xpath(f"//*[@id='main']/div[2]/div/div[1]/div/div[2]/div/div/ul/li[{i}]/div/div/a/div/div/div[1]/div[1]/div[2]/span").text)

# %%
mongofinal = pd.concat([mongo1, mongo2, mongo3, mongo4, mongo5, mongo6, mongo7, mongo8, mongo9, mongo10])

# %%
mongofinal = mongofinal.reset_index()

# %%
mongofinal.drop('index', axis=1, inplace=True)

# %%
lista =[]
for i in range(100):
    lista.append("MongoDB")

# %%
mongofinal['skills'] = lista

# %%
mongofinal
# Out:
#                                                 curso rating students  \
# 0                             Introduction to MongoDB    4.2      4.2
# 1   Server-side Development with NodeJS, Express a...    4.7      4.7
# 2     Introducción a bases de datos NoSQL con MongoDB   None     None
# 3     Create a C# Application to process MongoDB Data   None     None
# 4   Create a Python Application using PyMongo and ...    4.4      4.4
# ..                                                ...    ...      ...
# 95                          Embedded Interface Design    3.7      3.7
# 96  Master of Science in Machine Learning and Data...   None     None
# 97                    Введение в гладкие многообразия   None     None
# 98                                         Blockchain    4.6      4.6
# 99  Photography Basics and Beyond: From Smartphone...    4.7      4.7
#
#                        nivel  \
# 0               Intermediate
# 1               Intermediate
# 2   Coursera Project Network
# 3   Coursera Project Network
# 4               Intermediate
# ..                       ...
# 95              Intermediate
# 96   Imperial College London
# 97            HSE University
# 98              Intermediate
# 99                  Beginner
#
#                                           universidad   skills
# 0                                        MongoDB Inc.  MongoDB
# 1   The Hong Kong University of Science and Techno...  MongoDB
# 2                            Coursera Project Network  MongoDB
# 3                            Coursera Project Network  MongoDB
# 4                            Coursera Project Network  MongoDB
# ..                                                ...      ...
# 95                     University of Colorado Boulder  MongoDB
# 96                            Imperial College London  MongoDB
# 97                                     HSE University  MongoDB
# 98                              University at Buffalo  MongoDB
# 99                          Michigan State University  MongoDB
#
# [100 rows x 6 columns]

# %%
mongofinal.to_csv("mongo.csv")
